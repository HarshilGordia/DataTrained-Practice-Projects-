# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings 
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("baseball.csv")

# %%
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %%
df.isnull()
# Out:
#         W      R     AB      H     2B     3B     HR     BB     SO     SB  \
# 0   False  False  False  False  False  False  False  False  False  False
# 1   False  False  False  False  False  False  False  False  False  False
# 2   False  False  False  False  False  False  False  False  False  False
# 3   False  False  False  False  False  False  False  False  False  False
# 4   False  False  False  False  False  False  False  False  False  False
# 5   False  False  False  False  False  False  False  False  False  False
# 6   False  False  False  False  False  False  False  False  False  False
# 7   False  False  False  False  False  False  False  False  False  False
# 8   False  False  False  False  False  False  False  False  False  False
# 9   False  False  False  False  False  False  False  False  False  False
# 10  False  False  False  False  False  False  False  False  False  False
# 11  False  False  False  False  False  False  False  False  False  False
# ...

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# There is no blank space anywhere in graph hence we can conclude there is no null value present

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
cols=df.columns
df[cols].mean()
# Out:
# W        80.966667
# R       688.233333
# AB     5516.266667
# H      1403.533333
# 2B      274.733333
# 3B       31.300000
# HR      163.633333
# BB      469.100000
# SO     1248.200000
# SB       83.500000
# RA      688.233333
# ER      635.833333
# ERA       3.956333
# CG        3.466667
# SHO      11.300000
# SV       43.066667
# E        94.333333
# dtype: float64

# %%
df[cols].min()
# Out:
# W        63.00
# R       573.00
# AB     5385.00
# H      1324.00
# 2B      236.00
# 3B       13.00
# HR      100.00
# BB      375.00
# SO      973.00
# SB       44.00
# RA      525.00
# ER      478.00
# ERA       2.94
# CG        0.00
# SHO       4.00
# SV       28.00
# E        75.00
# dtype: float64

# %%
df[cols].max()
# Out:
# W       100.00
# R       891.00
# AB     5649.00
# H      1515.00
# 2B      308.00
# 3B       49.00
# HR      232.00
# BB      570.00
# SO     1518.00
# SB      134.00
# RA      844.00
# ER      799.00
# ERA       5.04
# CG       11.00
# SHO      21.00
# SV       62.00
# E       126.00
# dtype: float64

# %%
df.shape
# Out:
# (30, 17)

# %%
df['W'].value_counts()
# Out:
# 68     3
# 83     2
# 74     2
# 76     2
# 81     2
# 64     1
# 93     1
# 92     1
# 90     1
# 88     1
# 87     1
# 86     1
# 85     1
# 84     1
# 80     1
# 97     1
# 100    1
# 78     1
# 63     1
# 79     1
# 71     1
# 67     1
# 98     1
# 95     1
# Name: W, dtype: int64

# %%
(df['W'].value_counts()).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 68 is the number of wins for 3 times followed by 83,74,76 and 81 for 2 times and rest all with 1 time.

# %%
plt.figure(figsize=(16,10))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# Our target column is highly negative correlated to columns ERA,ER and RA.
#
# And is highly positive correlated to AB,CG and E

# %%
df.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
df.hist(figsize=(16,16))
# Out:
# array([[<AxesSubplot:title={'center':'W'}>,
#         <AxesSubplot:title={'center':'R'}>,
#         <AxesSubplot:title={'center':'AB'}>,
#         <AxesSubplot:title={'center':'H'}>],
#        [<AxesSubplot:title={'center':'2B'}>,
#         <AxesSubplot:title={'center':'3B'}>,
#         <AxesSubplot:title={'center':'HR'}>,
#         <AxesSubplot:title={'center':'BB'}>],
#        [<AxesSubplot:title={'center':'SO'}>,
#         <AxesSubplot:title={'center':'SB'}>,
#         <AxesSubplot:title={'center':'RA'}>,
#         <AxesSubplot:title={'center':'ER'}>],
#        [<AxesSubplot:title={'center':'ERA'}>,
#         <AxesSubplot:title={'center':'CG'}>,
#         <AxesSubplot:title={'center':'SHO'}>,
#         <AxesSubplot:title={'center':'SV'}>],
#        [<AxesSubplot:title={'center':'E'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %% [markdown]
# Here looking at the histograms we can find that few columns are such normally distributed and some have skewness.

# %%
fig,axes=plt.subplots(1,1,figsize=(12,8))
sns.scatterplot(x='AB',y='H',data=df)
# Out:
# <AxesSubplot:xlabel='AB', ylabel='H'>

# %% [markdown]
# Here we can observe that conversion rate decreases slightly as more balls hit bat

# %%
fig,axes=plt.subplots(1,1,figsize=(12,8))
sns.scatterplot(x='ERA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='W'>

# %% [markdown]
# Most of the wins are when the runs earned avg is 4.0 to 4.5

# %%
fig,axes=plt.subplots(1,1,figsize=(12,8))
sns.scatterplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %% [markdown]
# We can observe that most of the wins are when the homeruns are scored more than 140.

# %%
fig,axes=plt.subplots(1,1,figsize=(12,8))
sns.scatterplot(x='W',y='SV',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %% [markdown]
# Most of the wins are around 35-50 saves

# %%
for i in df[cols]:
    plt.figure
    sns.distplot(df[i])

# %% [markdown]
# We can observe that mostly columns are normally distributed

# %%
sns.pairplot(df)

# %% [markdown]
# We can check all the relations between the columns with this graph.

# %% [markdown]
# # Checking Outliers

# %%
df.plot(kind='box',subplots=True,layout=(3,7))
# Out:
# W         AxesSubplot(0.125,0.657941;0.0945122x0.222059)
# R      AxesSubplot(0.238415,0.657941;0.0945122x0.222059)
# AB     AxesSubplot(0.351829,0.657941;0.0945122x0.222059)
# H      AxesSubplot(0.465244,0.657941;0.0945122x0.222059)
# 2B     AxesSubplot(0.578659,0.657941;0.0945122x0.222059)
# 3B     AxesSubplot(0.692073,0.657941;0.0945122x0.222059)
# HR     AxesSubplot(0.805488,0.657941;0.0945122x0.222059)
# BB        AxesSubplot(0.125,0.391471;0.0945122x0.222059)
# SO     AxesSubplot(0.238415,0.391471;0.0945122x0.222059)
# SB     AxesSubplot(0.351829,0.391471;0.0945122x0.222059)
# RA     AxesSubplot(0.465244,0.391471;0.0945122x0.222059)
# ER     AxesSubplot(0.578659,0.391471;0.0945122x0.222059)
# ERA    AxesSubplot(0.692073,0.391471;0.0945122x0.222059)
# CG     AxesSubplot(0.805488,0.391471;0.0945122x0.222059)
# SHO          AxesSubplot(0.125,0.125;0.0945122x0.222059)
# SV        AxesSubplot(0.238415,0.125;0.0945122x0.222059)
# ...

# %% [markdown]
# few columns have outliers present

# %%
df['W'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['R'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['AB'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['H'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['2B'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['3B'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['E'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# There are very few outliers present in column E and R

# %%
from scipy.stats import zscore
zscr=np.abs(zscore(df))

threshold=3
print(np.where(zscr>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
zscr[5][1]
# Out:
# 3.5096470447193067

# %%
df_new=df[(zscr<3).all(axis=1)]

# %%
print(df.shape)
print('\n')
print(df_new.shape)
# Out:
# (30, 17)
#
#
# (29, 17)

# %%
df_new
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# ...

# %%
df_new.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
sns.distplot(df_new['H'])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(df_new['CG'])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(df_new['SHO'])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(df_new['SV'])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(df_new['E'])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %% [markdown]
# There is very less skewness present in some of the above graphs which are handled below

# %%
from sklearn.preprocessing import power_transform
dfnew = power_transform(df_new)

dfnew =pd.DataFrame(dfnew,columns=df_new.columns)

# %%
dfnew.skew()
# Out:
# W     -0.015560
# R     -0.024842
# AB     0.000000
# H      0.000000
# 2B    -0.052793
# 3B    -0.075139
# HR     0.000448
# BB    -0.008572
# SO     0.051530
# SB    -0.009570
# RA    -0.011974
# ER    -0.004988
# ERA   -0.000401
# CG    -0.045947
# SHO    0.000529
# SV    -0.000925
# E      0.065585
# dtype: float64

# %%
x=dfnew.drop(columns='W')
y=dfnew['W']

# %%
x.shape
# Out:
# (29, 16)

# %%
y.shape
# Out:
# (29,)

# %% [markdown]
# # Spliting Data into Traning Data and Testing Data

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=40)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (20, 16)
# (9, 16)
# (20,)
# (9,)

# %%
from sklearn.linear_model import LinearRegression
lg=LinearRegression()
lg.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lg.coef_
# Out:
# array([ 4.45103185e-01,  1.19904087e-14,  1.05748743e-14, -3.47569643e-01,
#         3.79800544e-01,  2.45492244e-01, -7.13110217e-02, -2.46133990e-01,
#        -1.18361564e-02,  7.38497468e-01, -2.80150073e+00,  1.77277887e+00,
#         3.15363427e-01,  8.85007776e-02,  5.32071951e-01, -1.44994756e-02])

# %%
lg.intercept_
# Out:
# -0.16256726209288747

# %%
lg.score(x_train,y_train)
# Out:
# 0.9881777838554905

# %%
pred=lg.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
print('R2 Score:',r2_score(y_test,pred))
print('\n')

print('error')
print('Mean absolute error:', mean_absolute_error(y_test,pred))
print('Mean squared error:', mean_squared_error(y_test,pred))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2 Score: -0.012796758791303375
#
#
# error
# Mean absolute error: 0.999093416279876
# Mean squared error: 1.2856108175275676
# Root Mean Squared Error: 1.1338477929279431

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lg,x,y,cv=10,scoring='neg_mean_squared_error')
lg_score_cross=np.sqrt(-score)
np.mean(lg_score_cross),np.std(lg_score_cross)
# Out:
# (0.4566298851021463, 0.14131799718286678)

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
rf.score(x_train,y_train)
# Out:
# 0.924876414083902

# %%
predrf=rf.predict(x_test)

# %%
print('R2 Score:',r2_score(y_test,predrf))
print('\n')

print('error')
print('Mean absolute error:', mean_absolute_error(y_test,predrf))
print('Mean squared error:', mean_squared_error(y_test,predrf))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,predrf)))
# Out:
# R2 Score: 0.36457206558551014
#
#
# error
# Mean absolute error: 0.7149280005476736
# Mean squared error: 0.8065912722878281
# Root Mean Squared Error: 0.898104265822086

# %%
rf=RandomForestRegressor()
score=cross_val_score(rf,x,y,cv=10,scoring='neg_mean_squared_error')
rf_score_cross=np.sqrt(-score)
np.mean(rf_score_cross),np.std(rf_score_cross)
# Out:
# (0.5890974596109946, 0.22949245082515657)

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(x_train,y_train)
preddt=dt.predict(x_test)

# %%
dt.score(x_train,y_train)
# Out:
# 1.0

# %%
print('R2 Score:',r2_score(y_test,preddt))
print('\n')

print('error')
print('Mean absolute error:', mean_absolute_error(y_test,preddt))
print('Mean squared error:', mean_squared_error(y_test,preddt))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,preddt)))
# Out:
# R2 Score: 0.5237984014494368
#
#
# error
# Mean absolute error: 0.5499713185107716
# Mean squared error: 0.6044746106327894
# Root Mean Squared Error: 0.7774796528738159

# %%
dt=DecisionTreeRegressor()
score=cross_val_score(dt,x,y,cv=10,scoring='neg_mean_squared_error')
dt_score_cross=np.sqrt(-score)
np.mean(dt_score_cross),np.std(dt_score_cross)
# Out:
# (0.772258487503077, 0.37007035846823255)

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(x_train,y_train)
predsv=sv.predict(x_test)

# %%
sv.score(x_train,y_train)
# Out:
# 0.953713949320607

# %%
print('R2 Score:',r2_score(y_test,predsv))
print('\n')

print('error')
print('Mean absolute error:', mean_absolute_error(y_test,predsv))
print('Mean squared error:', mean_squared_error(y_test,predsv))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,predsv)))
# Out:
# R2 Score: 0.1801902942267195
#
#
# error
# Mean absolute error: 0.8331362212304111
# Mean squared error: 1.040639414480393
# Root Mean Squared Error: 1.0201173532885288

# %%
sv=SVR()
score=cross_val_score(sv,x,y,cv=10,scoring='neg_mean_squared_error')
sv_score_cross=np.sqrt(-score)
np.mean(sv_score_cross),np.std(sv_score_cross)
# Out:
# (0.7205103743848125, 0.24170706467388164)

# %%
from sklearn.ensemble import AdaBoostRegressor
ada=AdaBoostRegressor()
ada.fit(x_train,y_train)
predg=ada.predict(x_test)

# %%
ada.score(x_train,y_train)
# Out:
# 0.9968028279953839

# %%
print('R2 Score:',r2_score(y_test,predg))
print('\n')

print('error')
print('Mean absolute error:', mean_absolute_error(y_test,predg))
print('Mean squared error:', mean_squared_error(y_test,predg))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,predg)))
# Out:
# R2 Score: 0.3581786612395562
#
#
# error
# Mean absolute error: 0.7506614147651915
# Mean squared error: 0.8147068489981993
# Root Mean Squared Error: 0.9026111283372255

# %%
ada=AdaBoostRegressor()
score=cross_val_score(ada,x,y,cv=10,scoring='neg_mean_squared_error')
ada_score_cross=np.sqrt(-score)
np.mean(ada_score_cross),np.std(ada_score_cross)
# Out:
# (0.6432759514531323, 0.16184444183217703)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr=GradientBoostingRegressor()
gbr.fit(x_train,y_train)
p=gbr.predict(x_test)

# %%
gbr.score(x_train,y_train)
# Out:
# 0.999999988445646

# %%
print('R2 Score:',r2_score(y_test,p))
print('\n')

print('error')
print('Mean absolute error:', mean_absolute_error(y_test,p))
print('Mean squared error:', mean_squared_error(y_test,p))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,p)))
# Out:
# R2 Score: 0.2247607486699662
#
#
# error
# Mean absolute error: 0.7008018462291317
# Mean squared error: 0.9840631489296017
# Root Mean Squared Error: 0.9919995710329726

# %%
gb=GradientBoostingRegressor()
score=cross_val_score(gb,x,y,cv=10,scoring='neg_mean_squared_error')
gb_score_cross=np.sqrt(-score)
np.mean(gb_score_cross),np.std(gb_score_cross)
# Out:
# (0.6913871553480504, 0.25290708144308277)

# %% [markdown]
# # Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn import svm, datasets

from sklearn.model_selection import GridSearchCV
parameters = {'kernel':['linear','poly','rbf'],'C':[1,10],'gamma':['scale', 'auto'] }
sv=SVR()
clf=GridSearchCV(sv,parameters)
clf.fit(x_train,y_train)
best_parameters =clf.best_params_
print(best_parameters)
best_result= clf.best_score_
print(best_result)
# Out:
# {'C': 1, 'gamma': 'scale', 'kernel': 'linear'}
# 0.7298565018438793

# %%
parameters = {'splitter':['best', 'random'],'max_features':['auto','sqrt','log2'],'criterion':['mse','mae','poisson'] }
dt=DecisionTreeRegressor()
ddt=GridSearchCV(dt,parameters)
ddt.fit(x_train,y_train)
best_parameters =ddt.best_params_
print(best_parameters)
best_result= ddt.best_score_
print(best_result)
# Out:
# {'criterion': 'mse', 'max_features': 'log2', 'splitter': 'best'}
# -0.09272476560582196

# %% [markdown]
# # Training model with best extracted parameters

# %%
sv=SVR(kernel='linear',gamma='scale',C=1)

# %%
sv.fit(x_train,y_train)
# Out:
# SVR(C=1, kernel='linear')

# %%
d=sv.predict(x_test)

# %%
print('R2 Score:',r2_score(y_test,d))
print('\n')

print('error')
print('Mean absolute error:', mean_absolute_error(y_test,d))
print('Mean squared error:', mean_squared_error(y_test,d))
print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,d)))
# Out:
# R2 Score: 0.4129692442034888
#
#
# error
# Mean absolute error: 0.7376987371339788
# Mean squared error: 0.7451574892222681
# Root Mean Squared Error: 0.8632250513175971

# %% [markdown]
# # Saving the best model

# %%
import joblib
joblib.dump(sv,'sv.obj')

svfile=joblib.load('sv.obj')
svfile.fit(x_train, y_train)
# Out:
# SVR(C=1, kernel='linear')
