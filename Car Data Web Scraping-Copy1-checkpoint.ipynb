# %%
import pandas as pd
import selenium
from selenium import webdriver
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver=webdriver.Chrome(r"C:\Users\Harshil Goradia\Downloads\chromedriver_win32\chromedriver")

# %%
driver.maximize_window()

# %%
driver.get("https://www.olx.in/cars_c84")

# %%
maha_btn=driver.find_elements_by_xpath("//ul[@class='_3eZBP _1TJht rui-1Culj _2XSBC']/li/ul/li/a")
for i in maha_btn:
    if i.text =='Kerala':
        i.click()
        break

# %%
#press this button 12-13 times.

button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link1=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link1.append(i.get_attribute("href"))

# %%
len(link1)
# Out:
# 513

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

# %%
for i in link1:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')

# %%
Car513= pd.DataFrame()
Car513['Model']=model
Car513['Variant']=variant
Car513['Location']=location
Car513['Fuel Type']=fuel
Car513['Transmission']=transmision
Car513['Kilometer']=kilometer
Car513['Owner']=owner
Car513['Price']=price
Car513
# Out:
#                           Model            Variant  \
# 0       Volkswagen Vento (2012)       1.6 Highline
# 1          Honda Mobilio (2014)           S i-DTEC
# 2    Maruti Suzuki Swift (2020)                VXI
# 3      Toyota Etios Liva (2011)   Etios Liva G SP*
# 4     Maruti Suzuki Ritz (2009)      2009-2011 VXI
# ..                          ...                ...
# 508         Toyota Camry (2008)  2002-2011 W4 (AT)
# 509  Maruti Suzuki Swift (2015)                VDI
# 510  Maruti Suzuki Swift (2013)                ZXI
# 511      Volkswagen Polo (2011)  1.0 MPI Trendline
# 512         Renault Kwid (2011)                AMT
#
#                                     Location Fuel Type Transmission  \
# 0    Location\nRailway Station Square, Aluva    PETROL       MANUAL
# 1                  Location\nEdapally, Kochi    DIESEL       MANUAL
# 2                  Location\nAyathil, Kollam    PETROL       MANUAL
# 3              Location\nNedumbassery, Kochi    PETROL       MANUAL
# ...

# %%
back_btn=driver.find_element_by_xpath("//ol[@class='rui-10Yqz']/li[3]/a")
back_btn.click()

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Delhi")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div[2]")
search_enter.click()

# %%
link2=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link2.append(i.get_attribute("href"))

# %%
len(link2)
# Out:
# 500

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link2:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')

# %%
Car_D= pd.DataFrame()
Car_D['Model']=model
Car_D['Variant']=variant
Car_D['Location']=location
Car_D['Fuel Type']=fuel
Car_D['Transmission']=transmision
Car_D['Kilometer']=kilometer
Car_D['Owner']=owner
Car_D['Price']=price
Car_D
# Out:
#                                 Model           Variant  \
# 0         Land Rover Discovery (2018)       HSE 3.0 Si6
# 1          Maruti Suzuki Swift (2018)          2018 LDI
# 2         Maruti Suzuki Ertiga (2013)               LDI
# 3              Mahindra Xuv500 (2014)  2011-2015 W6 2WD
# 4                   Honda Wr-V (2020)         i-DTEC VX
# ..                                ...               ...
# 495  Maruti Suzuki Wagon R 1.0 (2014)
# 496            Mahindra Xuv500 (2012)
# 497       Maruti Suzuki Ertiga (2015)
# 498  Maruti Suzuki Swift Dzire (2017)               VDI
# 499          Hyundai Elite I20 (2014)         Magna 1.2
#
#                             Location Fuel Type Transmission   Kilometer  \
# 0         Location\nVikaspuri, Delhi    PETROL    AUTOMATIC  41000.0 KM
# 1    Location\nRajendra Place, Delhi    DIESEL       MANUAL  69000.0 KM
# 2           Location\nKalkaji, Delhi    DIESEL       MANUAL  70000.0 KM
# ...

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Bangalore")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div[2]")
search_enter.click()

# %%
button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link3=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link3.append(i.get_attribute("href"))

# %%
len(link3)
# Out:
# 575

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link3:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')

# %%
Car_B= pd.DataFrame()
Car_B['Model']=model
Car_B['Variant']=variant
Car_B['Location']=location
Car_B['Fuel Type']=fuel
Car_B['Transmission']=transmision
Car_B['Kilometer']=kilometer
Car_B['Owner']=owner
Car_B['Price']=price
Car_B
# Out:
#                           Model                   Variant  \
# 0    Other Brands Others (2021)
# 1         Mahindra Logan (2007)            Diesel 1.5 DLX
# 2            Hyundai I20 (2013)                1.4 Sportz
# 3      Tata Indica Vista (2013)  2008-2013 Aqua TDI BSIII
# 4           Bajaj Others (2018)
# ..                          ...                       ...
# 570        Toyota Innova (2005)               2.5 V 7 STR
# 571         Toyota Etios (2018)                    1.4 GD
# 572       Nissan X-Trail (2005)         2004-2009 Comfort
# 573   Maruti Suzuki Ritz (2012)                    Others
# 574        Hyundai Xcent (2017)      2016-2017 1.1 CRDi S
#
#                                 Location Fuel Type Transmission   Kilometer  \
# 0     Location\nBangalore Highway, Dhone    DIESEL    AUTOMATIC       20 KM
# 1     Location\nBangalore Highway, Dhone    DIESEL    AUTOMATIC  170,000 KM
# 2     Location\nBangalore Highway, Dhone    DIESEL       MANUAL   78,000 KM
# ...

# %%
back_btn=driver.find_element_by_xpath("//ol[@class='rui-10Yqz']/li[3]/a")
back_btn.click()

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Indore")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div")
search_enter.click()

# %%
button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link4=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link4.append(i.get_attribute("href"))

# %%
len(link4)
# Out:
# 526

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link4:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')

# %%
Car_I= pd.DataFrame()
Car_I['Model']=model
Car_I['Variant']=variant
Car_I['Location']=location
Car_I['Fuel Type']=fuel
Car_I['Transmission']=transmision
Car_I['Kilometer']=kilometer
Car_I['Owner']=owner
Car_I['Price']=price
Car_I
# Out:
#                                   Model                             Variant  \
# 0      Maruti Suzuki Swift Dzire (2014)                                 VXI
# 1              Hyundai Grand I10 (2015)                 2013-2016 CRDi Asta
# 2                    Ford Aspire (2016)                              Others
# 3                  Mahindra Thar (2017)                                CRDe
# 4                 Renault Duster (2013)  2012-2015 85PS Diesel RxL Optional
# ..                                  ...                                 ...
# 521                Ford Ecosport (2014)             Titanium 1.5 TDCi (Opt)
# 522         Chevrolet Tavera Neo (2014)                              Others
# 523           Maruti Suzuki Ciaz (2019)                           1.4 Delta
# 524  Maruti Suzuki Vitara Brezza (2017)                                 ZDi
# 525                Hyundai Xcent (2015)               2014-2016 1.1 CRDi SX
#
# ...

# %%
back_btn=driver.find_element_by_xpath("//ol[@class='rui-10Yqz']/li[3]/a")
back_btn.click()

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Kolkata")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div")
search_enter.click()

# %%
button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link5=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link5.append(i.get_attribute("href"))

# %%
len(link5)
# Out:
# 540

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link5:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')    
        
        
Car_Ko= pd.DataFrame()
Car_Ko['Model']=model
Car_Ko['Variant']=variant
Car_Ko['Location']=location
Car_Ko['Fuel Type']=fuel
Car_Ko['Transmission']=transmision
Car_Ko['Kilometer']=kilometer
Car_Ko['Owner']=owner
Car_Ko['Price']=price
Car_Ko
# Out:
#                              Model                 Variant  \
# 0          Mahindra Tuv 300 (2019)                 T4 PLUS
# 1                Honda City (2016)      2015-2017 i DTec V
# 2              Jeep Compass (2018)  2.0 Limited Option 4X4
# 3             Hyundai Verna (2012)        2011-2014 1.6 SX
# 4            Renault Duster (2016)         85PS Diesel RxS
# ..                             ...                     ...
# 535   Maruti Suzuki Celerio (2015)           2014-2017 VXI
# 536              Honda City (2015)      2014-2015 i VTEC S
# 537              Honda Brio (2013)          2011-2013 V MT
# 538              Honda City (2010)      2008-2011 1.5 V MT
# 539  Maruti Suzuki Alto K10 (2014)                     LXI
#
#                                         Location Fuel Type Transmission  \
# 0                Location\nKankurgachhi, Kolkata    DIESEL       MANUAL
# 1           Location\nSaltlake Sector 1, Kolkata    DIESEL       MANUAL
# ...

# %%
back_btn=driver.find_element_by_xpath("//ol[@class='rui-10Yqz']/li[3]/a")
back_btn.click()

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Goa")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div")
search_enter.click()

# %%
button=driver.find_button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link6=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link6.append(i.get_attribute("href"))

# %%
len(link6)
# Out:
# 501

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link6:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')    
        
        
Car_Go= pd.DataFrame()
Car_Go['Model']=model
Car_Go['Variant']=variant
Car_Go['Location']=location
Car_Go['Fuel Type']=fuel
Car_Go['Transmission']=transmision
Car_Go['Kilometer']=kilometer
Car_Go['Owner']=owner
Car_Go['Price']=price
Car_Go
# Out:
#                                   Model                      Variant  \
# 0                     Honda Jazz (2015)                Exclusive CVT
# 1             Toyota Etios Cross (2014)              1.2 G X Edition
# 2          Maruti Suzuki Wagon R (2016)                      AMT VXI
# 3                    Hyundai I20 (2011)
# 4                    Honda Amaze (2016)                     S i-VTEC
# ..                                  ...                          ...
# 497           Maruti Suzuki Eeco (2015)           5 STR WITH A/C+HTR
# 498             Chevrolet Tavera (2004)  2003-2007 B1-10 seats BSIII
# 499            Maruti Suzuki Zen (2006)                 VXi - BS III
# 500               Renault Duster (2013)    2012-2015 85PS Diesel RxL
# 501  Maruti Suzuki Vitara Brezza (2017)                          VDi
#
#                                             Location Fuel Type Transmission  \
# 0               Location\nVidya Nagar, Vasco Da Gama    PETROL    AUTOMATIC
# ...

# %%
driver=webdriver.Chrome(r"C:\Users\Harshil Goradia\Downloads\chromedriver_win32\chromedriver")

driver.maximize_window()

driver.get("https://www.olx.in/cars_c84")

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Surat")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div")
search_enter.click()

# %%
button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link7=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link7.append(i.get_attribute("href"))

# %%
len(link7)
# Out:
# 652

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link7:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')    
        
        
Car_S= pd.DataFrame()
Car_S['Model']=model
Car_S['Variant']=variant
Car_S['Location']=locatioAn
Car_S['Fuel Type']=fuel
Car_S['Transmission']=transmision
Car_S['Kilometer']=kilometer
Car_S['Owner']=owner
Car_S['Price']=price
Car_S
# Out:
#                           Model               Variant  \
# 0    Maruti Suzuki Swift (2006)    2004-2010 ZXi BSIV
# 1              Ford Figo (2010)  2010-2012 Diesel ZXI
# 2    Maruti Suzuki Swift (2016)                   VDI
# 3    Maruti Suzuki Swift (2019)          AMT ZDI Plus
# 4              Mg Hector (2020)       Hybrid Sharp MT
# ..                          ...                   ...
# 647                           -                     -
# 648          Honda Amaze (2016)              S i-VTEC
# 649              Audi A6 (2009)     2009-2011 2.7 TDI
# 650          Honda Amaze (2015)              S i-DTEC
# 651  Maruti Suzuki Swift (2014)                   LXI
#
#                                   Location      Fuel Type Transmission  \
# 0           Location\nPaliwal Chowk, Surat  CNG & HYBRIDS       MANUAL
# 1    Location\nNew Panchsheel Nagar, Surat         DIESEL       MANUAL
# 2                 Location\nDindoli, Surat         DIESEL       MANUAL
# ...

# %%
back_btn=driver.find_element_by_xpath("//ol[@class='rui-10Yqz']/li[3]/a")
back_btn.click()

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Chennai")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div")
search_enter.click()

# %%
button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link8=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link8.append(i.get_attribute("href"))

# %%
len(link8)
# Out:
# 516

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link8:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-325-cba95f9c0253> in <module>
#      64 Car_C['Model']=model
#      65 Car_C['Variant']=variant
# ---> 66 Car_C['Location']=locatioan
#      67 Car_C['Fuel Type']=fuel
#      68 Car_C['Transmission']=transmision
#
# NameError: name 'locatioan' is not defined

# %%
Car_C= pd.DataFrame()
Car_C['Model']=model
Car_C['Variant']=variant
Car_C['Location']=location
Car_C['Fuel Type']=fuel
Car_C['Transmission']=transmision
Car_C['Kilometer']=kilometer
Car_C['Owner']=owner
Car_C['Price']=price
Car_C
# Out:
#                             Model                                 Variant  \
# 0    Hyundai Fluidic Verna (2015)                             1.6 CRDi SX
# 1                   Bmw X6 (2017)                      xDrive 40d M Sport
# 2               Honda Jazz (2019)                                  VX CVT
# 3       Maruti Suzuki Alto (2004)                           2000-2005 LXI
# 4       Mitsubishi Montero (2008)                       2007-2012 3.2 GLS
# ..                            ...                                     ...
# 511                             -                                       -
# 512      Hyundai Elite I20 (2017)                                Asta 1.2
# 513            Hyundai I20 (2009)                          2009-2011 Asta
# 514          Ford Ecosport (2018)                     1.5 Petrol Titanium
# 515          Ford Ecosport (2013)  2013-2015 1.5 DV5 MT Titanium Optional
#
#                                              Location Fuel Type Transmission  \
# ...

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Mumbai")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div")
search_enter.click()

# %%
button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link9=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link9.append(i.get_attribute("href"))

# %%
len(link9)
# Out:
# 561

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link9:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')    
        
        
Car_M= pd.DataFrame()
Car_M['Model']=model
Car_M['Variant']=variant
Car_M['Location']=location
Car_M['Fuel Type']=fuel
Car_M['Transmission']=transmision
Car_M['Kilometer']=kilometer
Car_M['Owner']=owner
Car_M['Price']=price
Car_M
# Out:
#                              Model                  Variant  \
# 0    Mercedes-Benz Gl-Class (2013)  Grand Edition Executive
# 1              Bmw 3 Series (2016)               320d Sport
# 2                Honda Jazz (2015)
# 3       Maruti Suzuki Swift (2009)       2004-2010 VDI BSIV
# 4     Maruti Suzuki Wagon R (2016)              CNG LXI Opt
# ..                             ...                      ...
# 556    Toyota Corolla Altis (2008)              Altis 1.8 J
# 557               Tata Bolt (2016)             Quadrajet XM
# 558            Toyota Etios (2017)                   1.4 GD
# 559           Toyota Qualis (2000)                    FS B4
# 560           Hyundai Xcent (2017)               1.2 VTVT E
#
#                                         Location Fuel Type Transmission  \
# 0               Location\nSantacruz West, Mumbai    DIESEL    AUTOMATIC
# 1                  Location\nBandra West, Mumbai    DIESEL    AUTOMATIC
# ...

# %%
back_btn=driver.find_element_by_xpath("//ol[@class='rui-10Yqz']/li[3]/a")
back_btn.click()

# %%
search=driver.find_element_by_xpath("//input[@class='_2xvhw']")
search.send_keys("Jaipur")

# %%
search_enter=driver.find_element_by_xpath("//div[@class='_2HzJo']/div")
search_enter.click()

# %%
button=driver.find_element_by_xpath("//button[@class='rui-39-wj rui-3evoE rui-1JPTg']")
button.click()

# %%
link10=[]
for i in driver.find_elements_by_xpath("//ul[@class='rl3f9 _3mXOU']//li/a"):
    link10.append(i.get_attribute("href"))

# %%
len(link10)
# Out:
# 480

# %%
model=[]
owner=[]
transmision=[]
fuel=[]
kilometer=[]
variant=[]
location=[]
price=[]

for i in link10:
    driver.get(i)
    
    try:
        model_=driver.find_element_by_xpath("//div[@class='_35xN1']")
        model.append(model_.text)
    except NoSuchElementException:
        model.append('-')
        
    try:
        location_=driver.find_element_by_xpath("//div[@class='_1l939']/div[2]/div[2]")
        location.append(location_.text)
    except NoSuchElementException:
        location.append('-')
        
        
    try:
        owner_=driver.find_element_by_xpath("//div[@class='_1l939']/div/div[2]")
        owner.append(owner_.text)
    except NoSuchElementException:    
        owner.append('-')
        
    try:
        trans_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[3]/div")
        transmision.append(trans_.text)
    except NoSuchElementException:
        transmision.append('-')    

    try:
        fuel_=driver.find_element_by_xpath("//div[@class='aOxkz']/div/div")
        fuel.append(fuel_.text)
    except NoSuchElementException:    
        fuel.append('-')    
        
    try:
        kilometer_=driver.find_element_by_xpath("//div[@class='aOxkz']/div[2]/div")
        kilometer.append(kilometer_.text)
    except NoSuchElementException:
        kilometer.append('-')
        
    try:
        variant_=driver.find_element_by_xpath("//div[@class='_3tLee']")
        variant.append(variant_.text)
    except NoSuchElementException:
        variant.append('-')    
     
    try:
        price_=driver.find_element_by_xpath("//div[@class='_3FkyT']")
        price.append(price_.text)
    except NoSuchElementException:
        price.append('-')    
        
        
Car_J= pd.DataFrame()
Car_J['Model']=model
Car_J['Variant']=variant
Car_J['Location']=location
Car_J['Fuel Type']=fuel
Car_J['Transmission']=transmision
Car_J['Kilometer']=kilometer
Car_J['Owner']=owner
Car_J['Price']=price
Car_J
# Out:
#                              Model           Variant  \
# 0                                -                 -
# 1        Tata Safari Storme (2015)                VX
# 2            Hyundai Santro (2009)  GLS II - Euro II
# 3                 Tata Nano (2011)      2009-2011 Cx
# 4    Maruti Suzuki Alto K10 (2018)                LX
# ..                             ...               ...
# 475          Hyundai Santro (2010)  GLS II - Euro II
# 476      Tata Safari Storme (2013)                EX
# 477           Hyundai Creta (2015)       1.6 CRDi SX
# 478                              -                 -
# 479       Mercedes-Benz Gls (2018)
#
#                               Location Fuel Type Transmission    Kilometer  \
# 0                                    -         -            -            -
# 1      Location\nEverest Vihar, Jaipur    DIESEL       MANUAL   70000.0 KM
# 2        Location\nJaman Nagar, Jaipur    PETROL       MANUAL   91000.0 KM
# ...

# %%
len(link1)+len(link2)+len(link3)+len(link4)+len(link5)+len(link6)+len(link7)+len(link8)+len(link9)+len(link10)
# Out:
# 5364

# %%
frames = [Car513, Car_D, Car_B, Car_I, Car_Ko, Car_Go, Car_S, Car_C, Car_M, Car_J]

# %%
Used_Cars = pd.concat(frames)

# %%
Used_Cars.reset_index(inplace = True, drop=True)
Used_Cars
# Out:
#                            Model           Variant  \
# 0        Volkswagen Vento (2012)      1.6 Highline
# 1           Honda Mobilio (2014)          S i-DTEC
# 2     Maruti Suzuki Swift (2020)               VXI
# 3       Toyota Etios Liva (2011)  Etios Liva G SP*
# 4      Maruti Suzuki Ritz (2009)     2009-2011 VXI
# ...                          ...               ...
# 5360       Hyundai Santro (2010)  GLS II - Euro II
# 5361   Tata Safari Storme (2013)                EX
# 5362        Hyundai Creta (2015)       1.6 CRDi SX
# 5363                           -                 -
# 5364    Mercedes-Benz Gls (2018)
#
#                                      Location Fuel Type Transmission  \
# 0     Location\nRailway Station Square, Aluva    PETROL       MANUAL
# 1                   Location\nEdapally, Kochi    DIESEL       MANUAL
# 2                   Location\nAyathil, Kollam    PETROL       MANUAL
# 3               Location\nNedumbassery, Kochi    PETROL       MANUAL
# ...

# %%
Used_Cars.to_csv('Used_Cars_Dataset')

# %%
Used_Cars_Dataset= pd.read_csv('Used_Cars_Dataset')
Used_Cars_Dataset.to_excel(r'C:\Users\Harshil Goradia\OneDrive\Desktop\Car Project\Cardataset.xlsx')
