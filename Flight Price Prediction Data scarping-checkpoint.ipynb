# %%
import csv
import sys
from datetime import date
import pandas as pd
import selenium.webdriver
import numpy as np
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from dateutil.relativedelta import relativedelta

# %%
#for exception
import linecache
import sys

def PrintException():
    exc_type, exc_obj, tb = sys.exc_info()
    f = tb.tb_frame
    lineno = tb.tb_lineno
    filename = f.f_code.co_filename
    linecache.checkcache(filename)
    line = linecache.getline(filename, lineno, f.f_globals)
    print('EXCEPTION IN ({}, LINE {} "{}"): {}'.format(filename, lineno, line.strip(), exc_obj))

# %%
def scrap(origin,destin,trDate):
    global none
  
    baseDataUrl = "https://www.makemytrip.com/flight/search?itinerary="+ origin +"-"+ destin +"-"+ trDate +"&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E"

    try:
        driver = selenium.webdriver.Chrome('chromedriver.exe') # Chrome driver is being used.
        print ("Requesting URL: " + baseDataUrl)

        driver.get(baseDataUrl)  			 # URL requested in browser.
        
        element_xpath = '//*[@id="left-side--wrapper"]/div[2]' # First box with relevant flight data.

        # Wait until the first box with relevant flight data appears on Screen
        element = WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.XPATH, element_xpath)))

        # Scroll the page till bottom to get full data available in the DOM.
        print ("Scrolling document upto bottom ...")
        for j in range(1, 100):
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Find the document body and get its inner HTML for processing in BeautifulSoup parser.
        body = driver.find_element_by_tag_name("body").get_attribute("innerHTML")

        print("Closing Chrome ...") # No more usage needed.
        driver.quit() 				# Browser Closed.

        print("Getting data from DOM ...")
        soupBody = BeautifulSoup(body) # Parse the inner HTML using BeautifulSoup
        
        # Extract the required tags 
        spanFlightName = soupBody.find_all("span", 'boldFont blackText airlineName')		# Tags with Flight Name
        print("spanFlightName  = " + str(len(spanFlightName)))

        Time = soupBody.find_all("p", {"class":"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})			# Tags with Departure Time
        print("Time Count in Scraping  = " + str(len(Time)))

        City = soupBody.findAll("p", {"class": "darkText"})				# Tags with Departure City
        print("City Count in Scraping  = " + str(len(City)))

        spanFlightCost = soupBody.findAll("p", {"class": "blackText fontSize18 blackFont white-space-no-wrap"})			# Tags with Flight Cost
        print("spanFlightCost Count in Scraping  = " + str(len(spanFlightCost)))

        pFlightStops = soupBody.findAll("p", {"class": "flightsLayoverInfo"})			# Tags with flight stops
        print("pFlightStops Count in Scraping  = " + str(len(pFlightStops)))
        
        transform(spanFlightName,trDate,City,Time,spanFlightCost,pFlightStops)



   
    except :
        PrintException()
        print(trDate," scraping complete")
        
        none =True

# %%
dates=(pd.date_range(start='30/10/2021', end='12/11/2021')) #dates 

New_date=[]
for i,date in enumerate(dates):
    day=str(date.day).zfill(2)   # 1 --->01,2--->02 conversion
    month=str(date.month).zfill(2)
    year=str(date.year)
    
    date=day+'/'+month+'/'+year  #formating date
    New_date.append(date)
print(New_date)
# Out:
# ['30/10/2021', '31/10/2021', '01/11/2021', '02/11/2021', '03/11/2021', '04/11/2021', '05/11/2021', '06/11/2021', '07/11/2021', '08/11/2021', '09/11/2021', '10/11/2021', '11/11/2021', '12/11/2021', '13/11/2021', '14/11/2021', '15/11/2021', '16/11/2021', '17/11/2021', '18/11/2021', '19/11/2021', '20/11/2021', '21/11/2021', '22/11/2021', '23/11/2021', '24/11/2021', '25/11/2021', '26/11/2021', '27/11/2021', '28/11/2021', '29/11/2021', '30/11/2021', '01/12/2021', '02/12/2021', '03/12/2021', '04/12/2021', '05/12/2021', '06/12/2021', '07/12/2021', '08/12/2021', '09/12/2021', '10/12/2021', '11/12/2021']

# %%
# various list container
Airline=[]
Journey_date=[]
From=[]
To=[]
Price=[]
Dtime=[]
Atime=[]
Stops=[]

flight_data = pd.DataFrame(np.nan, index=[0], columns=['Airline', 'Journey_date','From','To','Dtime','Atime','Stops','Price'])
flight_data.to_csv('Flight.csv')
#transforming scraped data 
def transform(spanFlightName,trDate,City,Time,spanFlightCost,pFlightStops):
    
    Airline.clear()
    Journey_date.clear()
    Price.clear()
    Stops.clear()
    From.clear()
    Dtime.clear()
    To.clear()
    Atime.clear()
    
    global flight_data
    print("Transaform Function Running.... ")
    for i in range(0,len(spanFlightName)):
        
        Airline.append(spanFlightName[i].string)
        Journey_date.append(trDate)
        Price.append(spanFlightCost[i].string)
        Stops.append(pFlightStops[i].string)
        
      
    for j in range(0,len(Time)):
        
        if(j%2==0):
            
            From.append(City[j].string)
            Dtime.append(Time[j].string)
        else:
            
            To.append(City[j].string)
            Atime.append(Time[j].string) 

            
            
    temp = {'Airline':Airline,
            'Journey_date':Journey_date,
            'From':From,
            'To':To,
            'Dtime':Dtime,
            'Atime':Atime,
            'Stops':Stops,
            'Price':Price}
    df=pd.DataFrame(temp)
    
    df.to_csv('Flight.csv', mode='a', header=False)
        
    flight_data = pd.concat([flight_data,df])
    flight_data=flight_data.reset_index(drop=True)
    display(flight_data)
    print('Lenght : ',len(flight_data))

# %%
## applying various state combination and extrating  1 month flight data

list_of_state=['RPR','GOI','AMD','IXC','IXR','IXW','VTZ','TIR','KUU','BLR','COK','IDR','PNQ','BOM','DEL','IMF','SHL','AJL','DMU','BBI','LUH','JAI','MAA','LKU','VNS','DED','CCU']
# 
for i in range(0,len(list_of_state)):
    orgin=list_of_state[i]
    for_to=list_of_state
    
    
    
    print("--------------")
    for j in range(0,len(for_to)):
        destin=for_to[j]
        none = False
        print("origin = "+orgin)
        print("destin = "+destin+'\n')
        
        if orgin!=destin:
            for i,date in enumerate(New_date) :
                if none !=True:
                    scrap(orgin,destin,date)
                    print(" ")
                else:
                    break
                
        else: 
            
            print( "-----Skiped-----")
            print(" ")
# Out:
# --------------
# origin = RPR
# destin = RPR
#
# -----Skiped-----
#
# origin = RPR
# destin = GOI
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-30/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 17
# Time Count in Scraping  = 34
# City Count in Scraping  = 34
# spanFlightCost Count in Scraping  = 17
# pFlightStops Count in Scraping  = 17
# Transaform Function Running....
#       Airline Journey_date    From   To  Dtime  Atime  \
# 0         NaN          NaN     NaN  NaN    NaN    NaN
# 1      IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2      IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3      IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4      IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# 5   Air India   30/10/2021  Raipur  Goa  12:30  20:30
# 6      IndiGo   30/10/2021  Raipur  Goa  10:00  15:30
# 7     Vistara   30/10/2021  Raipur  Goa  08:55  19:50
# 8   Air India   30/10/2021  Raipur  Goa  18:55  10:15
# 9      IndiGo   30/10/2021  Raipur  Goa  09:10  15:50
# 10  Air India   30/10/2021  Raipur  Goa  14:25  06:50
# 11    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 12    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 13    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 14    Vistara   30/10/2021  Raipur  Goa  20:20  12:45
# 15    Vistara   30/10/2021  Raipur  Goa  07:50  14:40
# 16  Air India   30/10/2021  Raipur  Goa  07:45  20:30
# 17  Air India   30/10/2021  Raipur  Goa  07:45  14:40
#
#                                         Stops     Price
# 0                                         NaN       NaN
# 1                           1 stop via Mumbai   ₹ 7,704
# 2                        1 stop via New Delhi   ₹ 7,704
# 3                        1 stop via New Delhi   ₹ 7,704
# 4                           1 stop via Indore   ₹ 8,544
# 5             2 stop via Visakhapatnam,Mumbai   ₹ 8,964
# 6                             1 stop via Pune  ₹ 10,812
# 7                        1 stop via New Delhi  ₹ 10,863
# 8       3 stop via New Delhi,Hyderabad,Mysore  ₹ 11,917
# 9                        1 stop via Bengaluru  ₹ 12,072
# 10      3 stop via Jagdalpur,Hyderabad,Mumbai  ₹ 12,481
# 11                2 stop via New Delhi,Mumbai  ₹ 13,498
# 12                2 stop via New Delhi,Mumbai  ₹ 13,498
# 13                2 stop via New Delhi,Mumbai  ₹ 13,498
# 14                2 stop via New Delhi,Mumbai  ₹ 13,551
# 15                  2 stop via Kolkata,Mumbai  ₹ 16,659
# 16  4 stop via Nagpur,New Delhi,Indore,Mumbai  ₹ 20,304
# 17                2 stop via Nagpur,New Delhi  ₹ 26,551
# Lenght :  18
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-31/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 16
# Time Count in Scraping  = 32
# City Count in Scraping  = 32
# spanFlightCost Count in Scraping  = 16
# pFlightStops Count in Scraping  = 16
# Transaform Function Running....
#       Airline Journey_date    From   To  Dtime  Atime  \
# 0         NaN          NaN     NaN  NaN    NaN    NaN
# 1      IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2      IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3      IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4      IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# 5   Air India   30/10/2021  Raipur  Goa  12:30  20:30
# 6      IndiGo   30/10/2021  Raipur  Goa  10:00  15:30
# 7     Vistara   30/10/2021  Raipur  Goa  08:55  19:50
# 8   Air India   30/10/2021  Raipur  Goa  18:55  10:15
# 9      IndiGo   30/10/2021  Raipur  Goa  09:10  15:50
# 10  Air India   30/10/2021  Raipur  Goa  14:25  06:50
# 11    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 12    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 13    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 14    Vistara   30/10/2021  Raipur  Goa  20:20  12:45
# 15    Vistara   30/10/2021  Raipur  Goa  07:50  14:40
# 16  Air India   30/10/2021  Raipur  Goa  07:45  20:30
# 17  Air India   30/10/2021  Raipur  Goa  07:45  14:40
# 18     IndiGo   31/10/2021  Raipur  Goa  10:00  14:00
# 19     IndiGo   31/10/2021  Raipur  Goa  10:30  14:10
# 20     IndiGo   31/10/2021  Raipur  Goa  08:40  15:15
# 21     IndiGo   31/10/2021  Raipur  Goa  09:45  15:35
# 22     IndiGo   31/10/2021  Raipur  Goa  10:00  17:25
# 23     IndiGo   31/10/2021  Raipur  Goa  08:40  18:00
# 24     IndiGo   31/10/2021  Raipur  Goa  11:30  18:20
# 25     IndiGo   31/10/2021  Raipur  Goa  09:15  18:20
# 26     IndiGo   31/10/2021  Raipur  Goa  09:45  18:25
# 27     IndiGo   31/10/2021  Raipur  Goa  15:35  20:50
# 28     IndiGo   31/10/2021  Raipur  Goa  11:30  21:30
# 29     IndiGo   31/10/2021  Raipur  Goa  09:15  21:30
# 30     IndiGo   31/10/2021  Raipur  Goa  20:35  07:05
# 31  Air India   31/10/2021  Raipur  Goa  12:30  20:30
# 32     IndiGo   31/10/2021  Raipur  Goa  09:05  14:35
# 33    Vistara   31/10/2021  Raipur  Goa  08:55  21:20
#
#                                         Stops     Price
# 0                                         NaN       NaN
# 1                           1 stop via Mumbai   ₹ 7,704
# 2                        1 stop via New Delhi   ₹ 7,704
# 3                        1 stop via New Delhi   ₹ 7,704
# 4                           1 stop via Indore   ₹ 8,544
# 5             2 stop via Visakhapatnam,Mumbai   ₹ 8,964
# 6                             1 stop via Pune  ₹ 10,812
# 7                        1 stop via New Delhi  ₹ 10,863
# 8       3 stop via New Delhi,Hyderabad,Mysore  ₹ 11,917
# 9                        1 stop via Bengaluru  ₹ 12,072
# 10      3 stop via Jagdalpur,Hyderabad,Mumbai  ₹ 12,481
# 11                2 stop via New Delhi,Mumbai  ₹ 13,498
# 12                2 stop via New Delhi,Mumbai  ₹ 13,498
# 13                2 stop via New Delhi,Mumbai  ₹ 13,498
# 14                2 stop via New Delhi,Mumbai  ₹ 13,551
# 15                  2 stop via Kolkata,Mumbai  ₹ 16,659
# 16  4 stop via Nagpur,New Delhi,Indore,Mumbai  ₹ 20,304
# 17                2 stop via Nagpur,New Delhi  ₹ 26,551
# 18                       1 stop via Hyderabad   ₹ 7,704
# 19                          1 stop via Indore   ₹ 7,704
# 20                          1 stop via Mumbai   ₹ 7,704
# 21                       1 stop via Bengaluru   ₹ 7,704
# 22                       1 stop via Hyderabad   ₹ 7,704
# 23                          1 stop via Mumbai   ₹ 7,704
# 24                       1 stop via New Delhi   ₹ 7,704
# 25                       1 stop via New Delhi   ₹ 7,704
# 26                       1 stop via Bengaluru   ₹ 7,704
# 27                       1 stop via Hyderabad   ₹ 7,704
# 28                       1 stop via New Delhi   ₹ 7,704
# 29                       1 stop via New Delhi   ₹ 7,704
# 30                       1 stop via Hyderabad   ₹ 7,704
# 31            2 stop via Visakhapatnam,Mumbai   ₹ 8,596
# 32                         1 stop via Kolkata   ₹ 8,859
# 33                       1 stop via New Delhi  ₹ 11,488
# Lenght :  34
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-01/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 23
# Time Count in Scraping  = 46
# City Count in Scraping  = 46
# spanFlightCost Count in Scraping  = 23
# pFlightStops Count in Scraping  = 23
# Transaform Function Running....
#       Airline Journey_date    From   To  Dtime  Atime  \
# 0         NaN          NaN     NaN  NaN    NaN    NaN
# 1      IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2      IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3      IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4      IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# 5   Air India   30/10/2021  Raipur  Goa  12:30  20:30
# 6      IndiGo   30/10/2021  Raipur  Goa  10:00  15:30
# 7     Vistara   30/10/2021  Raipur  Goa  08:55  19:50
# 8   Air India   30/10/2021  Raipur  Goa  18:55  10:15
# 9      IndiGo   30/10/2021  Raipur  Goa  09:10  15:50
# 10  Air India   30/10/2021  Raipur  Goa  14:25  06:50
# 11    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 12    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 13    Vistara   30/10/2021  Raipur  Goa  20:20  14:55
# 14    Vistara   30/10/2021  Raipur  Goa  20:20  12:45
# 15    Vistara   30/10/2021  Raipur  Goa  07:50  14:40
# 16  Air India   30/10/2021  Raipur  Goa  07:45  20:30
# 17  Air India   30/10/2021  Raipur  Goa  07:45  14:40
# 18     IndiGo   31/10/2021  Raipur  Goa  10:00  14:00
# 19     IndiGo   31/10/2021  Raipur  Goa  10:30  14:10
# 20     IndiGo   31/10/2021  Raipur  Goa  08:40  15:15
# 21     IndiGo   31/10/2021  Raipur  Goa  09:45  15:35
# 22     IndiGo   31/10/2021  Raipur  Goa  10:00  17:25
# 23     IndiGo   31/10/2021  Raipur  Goa  08:40  18:00
# 24     IndiGo   31/10/2021  Raipur  Goa  11:30  18:20
# 25     IndiGo   31/10/2021  Raipur  Goa  09:15  18:20
# 26     IndiGo   31/10/2021  Raipur  Goa  09:45  18:25
# 27     IndiGo   31/10/2021  Raipur  Goa  15:35  20:50
# 28     IndiGo   31/10/2021  Raipur  Goa  11:30  21:30
# 29     IndiGo   31/10/2021  Raipur  Goa  09:15  21:30
# 30     IndiGo   31/10/2021  Raipur  Goa  20:35  07:05
# 31  Air India   31/10/2021  Raipur  Goa  12:30  20:30
# 32     IndiGo   31/10/2021  Raipur  Goa  09:05  14:35
# 33    Vistara   31/10/2021  Raipur  Goa  08:55  21:20
# 34     IndiGo   01/11/2021  Raipur  Goa  10:30  14:10
# 35     IndiGo   01/11/2021  Raipur  Goa  09:45  18:25
# 36     IndiGo   01/11/2021  Raipur  Goa  10:00  14:00
# 37     IndiGo   01/11/2021  Raipur  Goa  08:40  15:15
# 38     IndiGo   01/11/2021  Raipur  Goa  09:45  15:35
# 39     IndiGo   01/11/2021  Raipur  Goa  10:00  17:25
# 40     IndiGo   01/11/2021  Raipur  Goa  08:40  18:00
# 41     IndiGo   01/11/2021  Raipur  Goa  11:30  18:20
# 42     IndiGo   01/11/2021  Raipur  Goa  09:15  18:20
# 43     IndiGo   01/11/2021  Raipur  Goa  15:35  20:50
# 44     IndiGo   01/11/2021  Raipur  Goa  11:30  21:30
# 45     IndiGo   01/11/2021  Raipur  Goa  09:15  21:30
# 46     IndiGo   01/11/2021  Raipur  Goa  20:35  07:05
# 47     IndiGo   01/11/2021  Raipur  Goa  09:05  14:35
# 48  Air India   01/11/2021  Raipur  Goa  12:30  20:30
# 49    Vistara   01/11/2021  Raipur  Goa  08:55  21:20
# 50  Air India   01/11/2021  Raipur  Goa  07:45  06:50
# 51  Air India   01/11/2021  Raipur  Goa  07:45  06:50
# 52  Air India   01/11/2021  Raipur  Goa  18:50  14:45
# 53  Air India   01/11/2021  Raipur  Goa  18:50  14:45
# 54  Air India   01/11/2021  Raipur  Goa  07:45  20:30
# 55    Vistara   01/11/2021  Raipur  Goa  20:20  12:45
# 56    Vistara   01/11/2021  Raipur  Goa  20:20  12:45
#
#                                         Stops     Price
# 0                                         NaN       NaN
# 1                           1 stop via Mumbai   ₹ 7,704
# 2                        1 stop via New Delhi   ₹ 7,704
# 3                        1 stop via New Delhi   ₹ 7,704
# 4                           1 stop via Indore   ₹ 8,544
# 5             2 stop via Visakhapatnam,Mumbai   ₹ 8,964
# 6                             1 stop via Pune  ₹ 10,812
# 7                        1 stop via New Delhi  ₹ 10,863
# 8       3 stop via New Delhi,Hyderabad,Mysore  ₹ 11,917
# 9                        1 stop via Bengaluru  ₹ 12,072
# 10      3 stop via Jagdalpur,Hyderabad,Mumbai  ₹ 12,481
# 11                2 stop via New Delhi,Mumbai  ₹ 13,498
# 12                2 stop via New Delhi,Mumbai  ₹ 13,498
# 13                2 stop via New Delhi,Mumbai  ₹ 13,498
# 14                2 stop via New Delhi,Mumbai  ₹ 13,551
# 15                  2 stop via Kolkata,Mumbai  ₹ 16,659
# 16  4 stop via Nagpur,New Delhi,Indore,Mumbai  ₹ 20,304
# 17                2 stop via Nagpur,New Delhi  ₹ 26,551
# 18                       1 stop via Hyderabad   ₹ 7,704
# 19                          1 stop via Indore   ₹ 7,704
# 20                          1 stop via Mumbai   ₹ 7,704
# 21                       1 stop via Bengaluru   ₹ 7,704
# 22                       1 stop via Hyderabad   ₹ 7,704
# 23                          1 stop via Mumbai   ₹ 7,704
# 24                       1 stop via New Delhi   ₹ 7,704
# 25                       1 stop via New Delhi   ₹ 7,704
# 26                       1 stop via Bengaluru   ₹ 7,704
# 27                       1 stop via Hyderabad   ₹ 7,704
# 28                       1 stop via New Delhi   ₹ 7,704
# 29                       1 stop via New Delhi   ₹ 7,704
# 30                       1 stop via Hyderabad   ₹ 7,704
# 31            2 stop via Visakhapatnam,Mumbai   ₹ 8,596
# 32                         1 stop via Kolkata   ₹ 8,859
# 33                       1 stop via New Delhi  ₹ 11,488
# 34                          1 stop via Indore   ₹ 7,257
# 35                       1 stop via Bengaluru   ₹ 7,651
# 36                       1 stop via Hyderabad   ₹ 7,704
# 37                          1 stop via Mumbai   ₹ 7,704
# 38                       1 stop via Bengaluru   ₹ 7,704
# 39                       1 stop via Hyderabad   ₹ 7,704
# 40                          1 stop via Mumbai   ₹ 7,704
# 41                       1 stop via New Delhi   ₹ 7,704
# 42                       1 stop via New Delhi   ₹ 7,704
# 43                       1 stop via Hyderabad   ₹ 7,704
# 44                       1 stop via New Delhi   ₹ 7,704
# 45                       1 stop via New Delhi   ₹ 7,704
# 46                       1 stop via Hyderabad   ₹ 7,704
# 47                         1 stop via Kolkata   ₹ 8,859
# 48            2 stop via Visakhapatnam,Mumbai   ₹ 9,384
# 49                       1 stop via New Delhi  ₹ 10,863
# 50  4 stop via Nagpur,New Delhi,Indore,Mumbai  ₹ 11,917
# 51         3 stop via Nagpur,New Delhi,Mumbai  ₹ 11,917
# 52                2 stop via New Delhi,Mumbai  ₹ 11,917
# 53                2 stop via New Delhi,Mumbai  ₹ 11,917
# 54  4 stop via Nagpur,New Delhi,Indore,Mumbai  ₹ 12,705
# 55                2 stop via New Delhi,Mumbai  ₹ 13,498
# 56                2 stop via New Delhi,Mumbai  ₹ 13,498
# Lenght :  57
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-02/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 11
# Time Count in Scraping  = 22
# City Count in Scraping  = 22
# spanFlightCost Count in Scraping  = 11
# pFlightStops Count in Scraping  = 11
# Transaform Function Running....
#       Airline Journey_date    From   To  Dtime  Atime  \
# 0         NaN          NaN     NaN  NaN    NaN    NaN
# 1      IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2      IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3      IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4      IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..        ...          ...     ...  ...    ...    ...
# 63     IndiGo   02/11/2021  Raipur  Goa  15:35  20:50
# 64     IndiGo   02/11/2021  Raipur  Goa  20:35  07:05
# 65     IndiGo   02/11/2021  Raipur  Goa  09:05  14:35
# 66  Air India   02/11/2021  Raipur  Goa  12:30  20:30
# 67    Vistara   02/11/2021  Raipur  Goa  20:20  14:55
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 63             1 stop via Hyderabad   ₹ 7,704
# 64             1 stop via Hyderabad   ₹ 7,704
# 65               1 stop via Kolkata   ₹ 8,859
# 66  2 stop via Visakhapatnam,Mumbai  ₹ 13,164
# 67      2 stop via New Delhi,Mumbai  ₹ 14,858
#
# [68 rows x 8 columns]
# Lenght :  68
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-03/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 19
# Time Count in Scraping  = 38
# City Count in Scraping  = 38
# spanFlightCost Count in Scraping  = 19
# pFlightStops Count in Scraping  = 19
# Transaform Function Running....
#     Airline Journey_date    From   To  Dtime  Atime  \
# 0       NaN          NaN     NaN  NaN    NaN    NaN
# 1    IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2    IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3    IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4    IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..      ...          ...     ...  ...    ...    ...
# 82  Vistara   03/11/2021  Raipur  Goa  20:20  14:55
# 83  Vistara   03/11/2021  Raipur  Goa  20:20  14:55
# 84  Vistara   03/11/2021  Raipur  Goa  20:20  14:55
# 85  Vistara   03/11/2021  Raipur  Goa  20:20  12:45
# 86  Vistara   03/11/2021  Raipur  Goa  20:20  12:45
#
#                           Stops     Price
# 0                           NaN       NaN
# 1             1 stop via Mumbai   ₹ 7,704
# 2          1 stop via New Delhi   ₹ 7,704
# 3          1 stop via New Delhi   ₹ 7,704
# 4             1 stop via Indore   ₹ 8,544
# ..                          ...       ...
# 82  2 stop via New Delhi,Mumbai  ₹ 15,331
# 83  2 stop via New Delhi,Mumbai  ₹ 15,331
# 84  2 stop via New Delhi,Mumbai  ₹ 15,331
# 85  2 stop via New Delhi,Mumbai  ₹ 19,846
# 86  2 stop via New Delhi,Mumbai  ₹ 19,846
#
# [87 rows x 8 columns]
# Lenght :  87
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-04/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 19
# Time Count in Scraping  = 38
# City Count in Scraping  = 38
# spanFlightCost Count in Scraping  = 19
# pFlightStops Count in Scraping  = 19
# Transaform Function Running....
#        Airline Journey_date    From   To  Dtime  Atime  \
# 0          NaN          NaN     NaN  NaN    NaN    NaN
# 1       IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2       IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3       IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4       IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..         ...          ...     ...  ...    ...    ...
# 101  Air India   04/11/2021  Raipur  Goa  12:30  20:30
# 102     IndiGo   04/11/2021  Raipur  Goa  09:05  14:35
# 103    Vistara   04/11/2021  Raipur  Goa  08:55  21:20
# 104     IndiGo   04/11/2021  Raipur  Goa  20:35  07:05
# 105  Air India   04/11/2021  Raipur  Goa  07:45  20:30
#
#                                          Stops     Price
# 0                                          NaN       NaN
# 1                            1 stop via Mumbai   ₹ 7,704
# 2                         1 stop via New Delhi   ₹ 7,704
# 3                         1 stop via New Delhi   ₹ 7,704
# 4                            1 stop via Indore   ₹ 8,544
# ..                                         ...       ...
# 101            2 stop via Visakhapatnam,Mumbai  ₹ 10,644
# 102                         1 stop via Kolkata  ₹ 10,812
# 103                       1 stop via New Delhi  ₹ 10,863
# 104                       1 stop via Hyderabad  ₹ 11,484
# 105  4 stop via Nagpur,New Delhi,Indore,Mumbai  ₹ 13,965
#
# [106 rows x 8 columns]
# Lenght :  106
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-05/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 9
# Time Count in Scraping  = 18
# City Count in Scraping  = 18
# spanFlightCost Count in Scraping  = 9
# pFlightStops Count in Scraping  = 9
# Transaform Function Running....
#                  Airline Journey_date    From   To  Dtime  Atime  \
# 0                    NaN          NaN     NaN  NaN    NaN    NaN
# 1                 IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2                 IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3                 IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4                 IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                   ...          ...     ...  ...    ...    ...
# 110               IndiGo   05/11/2021  Raipur  Goa  09:45  18:25
# 111  Air India, Go First   05/11/2021  Raipur  Goa  14:25  21:00
# 112               IndiGo   05/11/2021  Raipur  Goa  09:45  15:35
# 113               IndiGo   05/11/2021  Raipur  Goa  10:00  17:25
# 114              Vistara   05/11/2021  Raipur  Goa  08:55  21:20
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 110            1 stop via Bengaluru   ₹ 9,720
# 111  2 stop via Jagdalpur,Hyderabad  ₹ 10,057
# 112            1 stop via Bengaluru  ₹ 10,308
# 113            1 stop via Hyderabad  ₹ 10,308
# 114            1 stop via New Delhi  ₹ 19,359
#
# [115 rows x 8 columns]
# Lenght :  115
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-06/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 13
# Time Count in Scraping  = 26
# City Count in Scraping  = 26
# spanFlightCost Count in Scraping  = 13
# pFlightStops Count in Scraping  = 13
# Transaform Function Running....
#                Airline Journey_date    From   To  Dtime  Atime  \
# 0                  NaN          NaN     NaN  NaN    NaN    NaN
# 1               IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2               IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3               IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4               IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                 ...          ...     ...  ...    ...    ...
# 123             IndiGo   06/11/2021  Raipur  Goa  11:30  21:30
# 124             IndiGo   06/11/2021  Raipur  Goa  10:00  14:00
# 125            Vistara   06/11/2021  Raipur  Goa  20:20  09:45
# 126             IndiGo   06/11/2021  Raipur  Goa  10:30  14:10
# 127  Vistara, Go First   06/11/2021  Raipur  Goa  08:55  21:00
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 123            1 stop via New Delhi  ₹ 11,484
# 124            1 stop via Hyderabad  ₹ 13,668
# 125            1 stop via New Delhi  ₹ 13,675
# 126               1 stop via Indore  ₹ 14,529
# 127  2 stop via New Delhi,Hyderabad  ₹ 20,451
#
# [128 rows x 8 columns]
# Lenght :  128
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-07/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 20
# Time Count in Scraping  = 40
# City Count in Scraping  = 40
# spanFlightCost Count in Scraping  = 20
# pFlightStops Count in Scraping  = 20
# Transaform Function Running....
#              Airline Journey_date    From   To  Dtime  Atime  \
# 0                NaN          NaN     NaN  NaN    NaN    NaN
# 1             IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2             IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3             IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4             IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..               ...          ...     ...  ...    ...    ...
# 143          Vistara   07/11/2021  Raipur  Goa  20:20  13:50
# 144          Vistara   07/11/2021  Raipur  Goa  08:55  21:20
# 145          Vistara   07/11/2021  Raipur  Goa  20:20  12:45
# 146          Vistara   07/11/2021  Raipur  Goa  20:20  12:45
# 147  Vistara, IndiGo   07/11/2021  Raipur  Goa  08:55  20:50
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 143  2 stop via New Delhi,Bengaluru  ₹ 16,667
# 144            1 stop via New Delhi  ₹ 18,624
# 145     2 stop via New Delhi,Mumbai  ₹ 22,815
# 146     2 stop via New Delhi,Mumbai  ₹ 22,815
# 147  2 stop via New Delhi,Hyderabad  ₹ 23,287
#
# [148 rows x 8 columns]
# Lenght :  148
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-08/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 12
# Time Count in Scraping  = 24
# City Count in Scraping  = 24
# spanFlightCost Count in Scraping  = 12
# pFlightStops Count in Scraping  = 12
# Transaform Function Running....
#                 Airline Journey_date    From   To  Dtime  Atime  \
# 0                   NaN          NaN     NaN  NaN    NaN    NaN
# 1                IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2                IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3                IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4                IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                  ...          ...     ...  ...    ...    ...
# 155              IndiGo   08/11/2021  Raipur  Goa  09:15  18:20
# 156  Air India, AirAsia   08/11/2021  Raipur  Goa  14:25  07:00
# 157   Air India, IndiGo   08/11/2021  Raipur  Goa  14:25  20:50
# 158              IndiGo   08/11/2021  Raipur  Goa  10:30  14:10
# 159             Vistara   08/11/2021  Raipur  Goa  08:55  21:20
#
#                                         Stops     Price
# 0                                         NaN       NaN
# 1                           1 stop via Mumbai   ₹ 7,704
# 2                        1 stop via New Delhi   ₹ 7,704
# 3                        1 stop via New Delhi   ₹ 7,704
# 4                           1 stop via Indore   ₹ 8,544
# ..                                        ...       ...
# 155                      1 stop via New Delhi   ₹ 8,544
# 156  3 stop via Jagdalpur,Hyderabad,Bengaluru   ₹ 9,162
# 157            2 stop via Jagdalpur,Hyderabad   ₹ 9,689
# 158                         1 stop via Indore  ₹ 10,959
# 159                      1 stop via New Delhi  ₹ 13,675
#
# [160 rows x 8 columns]
# Lenght :  160
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-09/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 25
# Time Count in Scraping  = 50
# City Count in Scraping  = 50
# spanFlightCost Count in Scraping  = 25
# pFlightStops Count in Scraping  = 25
# Transaform Function Running....
#      Airline Journey_date    From   To  Dtime  Atime                 Stops  \
# 0        NaN          NaN     NaN  NaN    NaN    NaN                   NaN
# 1     IndiGo   30/10/2021  Raipur  Goa  07:30  12:40     1 stop via Mumbai
# 2     IndiGo   30/10/2021  Raipur  Goa  08:05  14:50  1 stop via New Delhi
# 3     IndiGo   30/10/2021  Raipur  Goa  12:10  21:20  1 stop via New Delhi
# 4     IndiGo   30/10/2021  Raipur  Goa  10:25  14:10     1 stop via Indore
# ..       ...          ...     ...  ...    ...    ...                   ...
# 180  Vistara   09/11/2021  Raipur  Goa  08:55  21:20  1 stop via New Delhi
# 181   IndiGo   09/11/2021  Raipur  Goa  16:55  00:20  1 stop via New Delhi
# 182   IndiGo   09/11/2021  Raipur  Goa  16:55  02:25  1 stop via New Delhi
# 183   IndiGo   09/11/2021  Raipur  Goa  08:40  15:15     1 stop via Mumbai
# 184   IndiGo   09/11/2021  Raipur  Goa  08:40  18:00     1 stop via Mumbai
#
#         Price
# 0         NaN
# 1     ₹ 7,704
# 2     ₹ 7,704
# 3     ₹ 7,704
# 4     ₹ 8,544
# ..        ...
# 180  ₹ 11,488
# 181  ₹ 12,796
# 182  ₹ 12,796
# 183  ₹ 14,424
# 184  ₹ 14,424
#
# [185 rows x 8 columns]
# Lenght :  185
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-10/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 16
# Time Count in Scraping  = 32
# City Count in Scraping  = 32
# spanFlightCost Count in Scraping  = 16
# pFlightStops Count in Scraping  = 16
# Transaform Function Running....
#                 Airline Journey_date    From   To  Dtime  Atime  \
# 0                   NaN          NaN     NaN  NaN    NaN    NaN
# 1                IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2                IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3                IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4                IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                  ...          ...     ...  ...    ...    ...
# 196  Air India, AirAsia   10/11/2021  Raipur  Goa  14:25  07:00
# 197   Air India, IndiGo   10/11/2021  Raipur  Goa  14:25  20:50
# 198              IndiGo   10/11/2021  Raipur  Goa  10:30  14:10
# 199    IndiGo, Go First   10/11/2021  Raipur  Goa  10:00  21:00
# 200             Vistara   10/11/2021  Raipur  Goa  08:55  21:20
#
#                                         Stops     Price
# 0                                         NaN       NaN
# 1                           1 stop via Mumbai   ₹ 7,704
# 2                        1 stop via New Delhi   ₹ 7,704
# 3                        1 stop via New Delhi   ₹ 7,704
# 4                           1 stop via Indore   ₹ 8,544
# ..                                        ...       ...
# 196  3 stop via Jagdalpur,Hyderabad,Bengaluru   ₹ 9,740
# 197            2 stop via Jagdalpur,Hyderabad   ₹ 9,952
# 198                         1 stop via Indore  ₹ 10,014
# 199                      1 stop via Hyderabad  ₹ 11,998
# 200                      1 stop via New Delhi  ₹ 12,068
#
# [201 rows x 8 columns]
# Lenght :  201
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-11/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 25
# Time Count in Scraping  = 50
# City Count in Scraping  = 50
# spanFlightCost Count in Scraping  = 25
# pFlightStops Count in Scraping  = 25
# Transaform Function Running....
#      Airline Journey_date    From   To  Dtime  Atime                 Stops  \
# 0        NaN          NaN     NaN  NaN    NaN    NaN                   NaN
# 1     IndiGo   30/10/2021  Raipur  Goa  07:30  12:40     1 stop via Mumbai
# 2     IndiGo   30/10/2021  Raipur  Goa  08:05  14:50  1 stop via New Delhi
# 3     IndiGo   30/10/2021  Raipur  Goa  12:10  21:20  1 stop via New Delhi
# 4     IndiGo   30/10/2021  Raipur  Goa  10:25  14:10     1 stop via Indore
# ..       ...          ...     ...  ...    ...    ...                   ...
# 221   IndiGo   11/11/2021  Raipur  Goa  08:40  15:15     1 stop via Mumbai
# 222  Vistara   11/11/2021  Raipur  Goa  08:55  21:20  1 stop via New Delhi
# 223   IndiGo   11/11/2021  Raipur  Goa  20:35  07:05  1 stop via Hyderabad
# 224   IndiGo   11/11/2021  Raipur  Goa  11:30  18:20  1 stop via New Delhi
# 225   IndiGo   11/11/2021  Raipur  Goa  09:05  14:35    1 stop via Kolkata
#
#         Price
# 0         NaN
# 1     ₹ 7,704
# 2     ₹ 7,704
# 3     ₹ 7,704
# 4     ₹ 8,544
# ..        ...
# 221  ₹ 12,639
# 222  ₹ 12,782
# 223  ₹ 13,111
# 224  ₹ 13,479
# 225  ₹ 15,211
#
# [226 rows x 8 columns]
# Lenght :  226
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-12/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 29
# Time Count in Scraping  = 58
# City Count in Scraping  = 58
# spanFlightCost Count in Scraping  = 29
# pFlightStops Count in Scraping  = 29
# Transaform Function Running....
#     Airline Journey_date    From   To  Dtime  Atime                 Stops  \
# 0       NaN          NaN     NaN  NaN    NaN    NaN                   NaN
# 1    IndiGo   30/10/2021  Raipur  Goa  07:30  12:40     1 stop via Mumbai
# 2    IndiGo   30/10/2021  Raipur  Goa  08:05  14:50  1 stop via New Delhi
# 3    IndiGo   30/10/2021  Raipur  Goa  12:10  21:20  1 stop via New Delhi
# 4    IndiGo   30/10/2021  Raipur  Goa  10:25  14:10     1 stop via Indore
# ..      ...          ...     ...  ...    ...    ...                   ...
# 250  IndiGo   12/11/2021  Raipur  Goa  11:30  21:30  1 stop via New Delhi
# 251  IndiGo   12/11/2021  Raipur  Goa  10:30  14:10     1 stop via Indore
# 252  IndiGo   12/11/2021  Raipur  Goa  09:15  18:20  1 stop via New Delhi
# 253  IndiGo   12/11/2021  Raipur  Goa  11:30  18:20  1 stop via New Delhi
# 254  IndiGo   12/11/2021  Raipur  Goa  10:00  14:00  1 stop via Hyderabad
#
#         Price
# 0         NaN
# 1     ₹ 7,704
# 2     ₹ 7,704
# 3     ₹ 7,704
# 4     ₹ 8,544
# ..        ...
# 250  ₹ 14,319
# 251  ₹ 14,529
# 252  ₹ 15,306
# 253  ₹ 15,673
# 254  ₹ 16,156
#
# [255 rows x 8 columns]
# Lenght :  255
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-13/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 29
# Time Count in Scraping  = 58
# City Count in Scraping  = 58
# spanFlightCost Count in Scraping  = 29
# pFlightStops Count in Scraping  = 29
# Transaform Function Running....
#                Airline Journey_date    From   To  Dtime  Atime  \
# 0                  NaN          NaN     NaN  NaN    NaN    NaN
# 1               IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2               IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3               IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4               IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                 ...          ...     ...  ...    ...    ...
# 279             IndiGo   13/11/2021  Raipur  Goa  10:00  14:00
# 280             IndiGo   13/11/2021  Raipur  Goa  08:40  15:15
# 281             IndiGo   13/11/2021  Raipur  Goa  08:40  18:00
# 282  Vistara, Go First   13/11/2021  Raipur  Goa  08:55  21:00
# 283             IndiGo   13/11/2021  Raipur  Goa  09:05  14:35
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 279            1 stop via Hyderabad  ₹ 14,581
# 280               1 stop via Mumbai  ₹ 14,634
# 281               1 stop via Mumbai  ₹ 14,739
# 282  2 stop via New Delhi,Hyderabad  ₹ 15,182
# 283              1 stop via Kolkata  ₹ 20,671
#
# [284 rows x 8 columns]
# Lenght :  284
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-14/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 17
# Time Count in Scraping  = 34
# City Count in Scraping  = 34
# spanFlightCost Count in Scraping  = 17
# pFlightStops Count in Scraping  = 17
# Transaform Function Running....
#                Airline Journey_date    From   To  Dtime  Atime  \
# 0                  NaN          NaN     NaN  NaN    NaN    NaN
# 1               IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2               IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3               IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4               IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                 ...          ...     ...  ...    ...    ...
# 296             IndiGo   14/11/2021  Raipur  Goa  15:35  20:50
# 297             IndiGo   14/11/2021  Raipur  Goa  10:00  14:00
# 298             IndiGo   14/11/2021  Raipur  Goa  09:05  14:35
# 299            Vistara   14/11/2021  Raipur  Goa  08:55  21:20
# 300  Vistara, Go First   14/11/2021  Raipur  Goa  08:55  21:00
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 296            1 stop via Hyderabad  ₹ 10,119
# 297            1 stop via Hyderabad  ₹ 10,696
# 298              1 stop via Kolkata  ₹ 10,812
# 299            1 stop via New Delhi  ₹ 12,068
# 300  2 stop via New Delhi,Hyderabad  ₹ 16,610
#
# [301 rows x 8 columns]
# Lenght :  301
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-15/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 26
# Time Count in Scraping  = 52
# City Count in Scraping  = 52
# spanFlightCost Count in Scraping  = 26
# pFlightStops Count in Scraping  = 26
# Transaform Function Running....
#                Airline Journey_date    From   To  Dtime  Atime  \
# 0                  NaN          NaN     NaN  NaN    NaN    NaN
# 1               IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2               IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3               IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4               IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                 ...          ...     ...  ...    ...    ...
# 322             IndiGo   15/11/2021  Raipur  Goa  10:30  14:10
# 323  Air India, IndiGo   15/11/2021  Raipur  Goa  14:25  20:50
# 324             IndiGo   15/11/2021  Raipur  Goa  15:35  20:50
# 325            Vistara   15/11/2021  Raipur  Goa  08:55  21:20
# 326  Vistara, Go First   15/11/2021  Raipur  Goa  08:55  21:00
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 322               1 stop via Indore   ₹ 9,489
# 323  2 stop via Jagdalpur,Hyderabad   ₹ 9,689
# 324            1 stop via Hyderabad   ₹ 9,804
# 325            1 stop via New Delhi  ₹ 11,488
# 326  2 stop via New Delhi,Hyderabad  ₹ 14,690
#
# [327 rows x 8 columns]
# Lenght :  327
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-16/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 30
# Time Count in Scraping  = 60
# City Count in Scraping  = 60
# spanFlightCost Count in Scraping  = 30
# pFlightStops Count in Scraping  = 30
# Transaform Function Running....
#                Airline Journey_date    From   To  Dtime  Atime  \
# 0                  NaN          NaN     NaN  NaN    NaN    NaN
# 1               IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2               IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3               IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4               IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                 ...          ...     ...  ...    ...    ...
# 352             IndiGo   16/11/2021  Raipur  Goa  11:30  18:20
# 353             IndiGo   16/11/2021  Raipur  Goa  09:15  18:20
# 354  Vistara, Go First   16/11/2021  Raipur  Goa  08:55  21:00
# 355             IndiGo   16/11/2021  Raipur  Goa  10:30  14:10
# 356             IndiGo   16/11/2021  Raipur  Goa  09:05  14:35
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 352            1 stop via New Delhi  ₹ 13,111
# 353            1 stop via New Delhi  ₹ 13,479
# 354  2 stop via New Delhi,Hyderabad  ₹ 14,065
# 355               1 stop via Indore  ₹ 14,529
# 356              1 stop via Kolkata  ₹ 19,716
#
# [357 rows x 8 columns]
# Lenght :  357
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-17/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 23
# Time Count in Scraping  = 46
# City Count in Scraping  = 46
# spanFlightCost Count in Scraping  = 23
# pFlightStops Count in Scraping  = 23
# Transaform Function Running....
#     Airline Journey_date    From   To  Dtime  Atime                 Stops  \
# 0       NaN          NaN     NaN  NaN    NaN    NaN                   NaN
# 1    IndiGo   30/10/2021  Raipur  Goa  07:30  12:40     1 stop via Mumbai
# 2    IndiGo   30/10/2021  Raipur  Goa  08:05  14:50  1 stop via New Delhi
# 3    IndiGo   30/10/2021  Raipur  Goa  12:10  21:20  1 stop via New Delhi
# 4    IndiGo   30/10/2021  Raipur  Goa  10:25  14:10     1 stop via Indore
# ..      ...          ...     ...  ...    ...    ...                   ...
# 375  IndiGo   17/11/2021  Raipur  Goa  09:05  14:35    1 stop via Kolkata
# 376  IndiGo   17/11/2021  Raipur  Goa  10:00  14:00  1 stop via Hyderabad
# 377  IndiGo   17/11/2021  Raipur  Goa  20:35  07:05  1 stop via Hyderabad
# 378  IndiGo   17/11/2021  Raipur  Goa  16:55  00:20  1 stop via New Delhi
# 379  IndiGo   17/11/2021  Raipur  Goa  16:55  02:25  1 stop via New Delhi
#
#         Price
# 0         NaN
# 1     ₹ 7,704
# 2     ₹ 7,704
# 3     ₹ 7,704
# 4     ₹ 8,544
# ..        ...
# 375  ₹ 11,484
# 376  ₹ 11,848
# 377  ₹ 12,009
# 378  ₹ 12,429
# 379  ₹ 12,429
#
# [380 rows x 8 columns]
# Lenght :  380
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-18/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 17
# Time Count in Scraping  = 34
# City Count in Scraping  = 34
# spanFlightCost Count in Scraping  = 17
# pFlightStops Count in Scraping  = 17
# Transaform Function Running....
#                Airline Journey_date    From   To  Dtime  Atime  \
# 0                  NaN          NaN     NaN  NaN    NaN    NaN
# 1               IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2               IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3               IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4               IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..                 ...          ...     ...  ...    ...    ...
# 392    IndiGo, AirAsia   18/11/2021  Raipur  Goa  10:00  22:00
# 393             IndiGo   18/11/2021  Raipur  Goa  15:35  20:50
# 394  Air India, IndiGo   18/11/2021  Raipur  Goa  14:25  20:50
# 395            Vistara   18/11/2021  Raipur  Goa  08:55  21:20
# 396             IndiGo   18/11/2021  Raipur  Goa  10:30  14:10
#
#                               Stops     Price
# 0                               NaN       NaN
# 1                 1 stop via Mumbai   ₹ 7,704
# 2              1 stop via New Delhi   ₹ 7,704
# 3              1 stop via New Delhi   ₹ 7,704
# 4                 1 stop via Indore   ₹ 8,544
# ..                              ...       ...
# 392  2 stop via Hyderabad,Bengaluru   ₹ 9,689
# 393            1 stop via Hyderabad   ₹ 9,751
# 394  2 stop via Jagdalpur,Hyderabad  ₹ 10,004
# 395            1 stop via New Delhi  ₹ 12,782
# 396               1 stop via Indore  ₹ 13,269
#
# [397 rows x 8 columns]
# Lenght :  397
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-19/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 17
# Time Count in Scraping  = 34
# City Count in Scraping  = 34
# spanFlightCost Count in Scraping  = 17
# pFlightStops Count in Scraping  = 17
# Transaform Function Running....
#        Airline Journey_date    From   To  Dtime  Atime  \
# 0          NaN          NaN     NaN  NaN    NaN    NaN
# 1       IndiGo   30/10/2021  Raipur  Goa  07:30  12:40
# 2       IndiGo   30/10/2021  Raipur  Goa  08:05  14:50
# 3       IndiGo   30/10/2021  Raipur  Goa  12:10  21:20
# 4       IndiGo   30/10/2021  Raipur  Goa  10:25  14:10
# ..         ...          ...     ...  ...    ...    ...
# 409  Air India   19/11/2021  Raipur  Goa  12:30  20:30
# 410     IndiGo   19/11/2021  Raipur  Goa  08:40  15:15
# 411    Vistara   19/11/2021  Raipur  Goa  08:55  21:20
# 412  Air India   19/11/2021  Raipur  Goa  18:50  00:35
# 413     IndiGo   19/11/2021  Raipur  Goa  10:30  14:10
#
#                                Stops     Price
# 0                                NaN       NaN
# 1                  1 stop via Mumbai   ₹ 7,704
# 2               1 stop via New Delhi   ₹ 7,704
# 3               1 stop via New Delhi   ₹ 7,704
# 4                  1 stop via Indore   ₹ 8,544
# ..                               ...       ...
# 409  2 stop via Visakhapatnam,Mumbai   ₹ 9,279
# 410                1 stop via Mumbai  ₹ 10,224
# 411             1 stop via New Delhi  ₹ 12,068
# 412             1 stop via New Delhi  ₹ 12,971
# 413                1 stop via Indore  ₹ 14,529
#
# [414 rows x 8 columns]
# Lenght :  414
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-GOI-20/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 19
# Time Count in Scraping  = 38
# City Count in Scraping  = 38
# spanFlightCost Count in Scraping  = 19
# pFlightStops Count in Scraping  = 19
# Transaform Function Running....
#        Airline Journey_date    From   To  Dtime  Atime                 Stops  \
# 0          NaN          NaN     NaN  NaN    NaN    NaN                   NaN
# 1       IndiGo   30/10/2021  Raipur  Goa  07:30  12:40     1 stop via Mumbai
# 2       IndiGo   30/10/2021  Raipur  Goa  08:05  14:50  1 stop via New Delhi
# 3       IndiGo   30/10/2021  Raipur  Goa  12:10  21:20  1 stop via New Delhi
# 4       IndiGo   30/10/2021  Raipur  Goa  10:25  14:10     1 stop via Indore
# ..         ...          ...     ...  ...    ...    ...                   ...
# 428     IndiGo   20/11/2021  Raipur  Goa  10:30  14:10     1 stop via Indore
# 429     IndiGo   20/11/2021  Raipur  Goa  08:40  15:15     1 stop via Mumbai
# 430    Vistara   20/11/2021  Raipur  Goa  08:55  21:20  1 stop via New Delhi
# 431  Air India   20/11/2021  Raipur  Goa  18:50  00:35  1 stop via New Delhi
# 432     IndiGo   20/11/2021  Raipur  Goa  10:00  14:00  1 stop via Hyderabad
#
#         Price
# 0         NaN
# 1     ₹ 7,704
# 2     ₹ 7,704
# 3     ₹ 7,704
# 4     ₹ 8,544
# ..        ...
# 428  ₹ 10,014
# 429  ₹ 10,591
# 430  ₹ 12,068
# 431  ₹ 12,142
# 432  ₹ 13,111
#
# [433 rows x 8 columns]
# Lenght :  433
#
# ...
# from disconnected: unable to send message to renderer
#   (Session info: chrome=95.0.4638.54)
#
# 01/12/2021  scraping complete
#
# origin = RPR
# destin = IXW
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-IXW-30/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# EXCEPTION IN (<ipython-input-7-5312db3adbf2>, LINE 25 "element = WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.XPATH, element_xpath)))"): Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=95.0.4638.54)
#
# 30/10/2021  scraping complete
#
# origin = RPR
# destin = VTZ
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-VTZ-30/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# EXCEPTION IN (<ipython-input-7-5312db3adbf2>, LINE 19 "driver.get(baseDataUrl)  			 # URL requested in browser."): Message: unknown error: cannot determine loading status
# from disconnected: received Inspector.detached event
#   (Session info: chrome=95.0.4638.54)
#
# 30/10/2021  scraping complete
#
# origin = RPR
# destin = TIR
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-TIR-30/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# EXCEPTION IN (<ipython-input-7-5312db3adbf2>, LINE 25 "element = WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.XPATH, element_xpath)))"): Message: chrome not reachable
#   (Session info: chrome=95.0.4638.54)
#
# 30/10/2021  scraping complete
#
# origin = RPR
# destin = KUU
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-KUU-30/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# EXCEPTION IN (<ipython-input-7-5312db3adbf2>, LINE 25 "element = WebDriverWait(driver, 15).until(EC.visibility_of_element_located((By.XPATH, element_xpath)))"): Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=95.0.4638.54)
#
# 30/10/2021  scraping complete
#
# origin = RPR
# destin = BLR
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-BLR-30/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# EXCEPTION IN (<ipython-input-7-5312db3adbf2>, LINE 19 "driver.get(baseDataUrl)  			 # URL requested in browser."): Message: unknown error: cannot determine loading status
# from disconnected: received Inspector.detached event
#   (Session info: chrome=95.0.4638.54)
#
# 30/10/2021  scraping complete
#
# origin = RPR
# destin = COK
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-30/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 12
# Time Count in Scraping  = 24
# City Count in Scraping  = 24
# spanFlightCost Count in Scraping  = 12
# pFlightStops Count in Scraping  = 12
# Transaform Function Running....
#       Airline Journey_date    From     To  Dtime  Atime                 Stops  \
# 0         NaN          NaN     NaN    NaN    NaN    NaN                   NaN
# 1      IndiGo   30/10/2021  Raipur    Goa  07:30  12:40     1 stop via Mumbai
# 2      IndiGo   30/10/2021  Raipur    Goa  08:05  14:50  1 stop via New Delhi
# 3      IndiGo   30/10/2021  Raipur    Goa  12:10  21:20  1 stop via New Delhi
# 4      IndiGo   30/10/2021  Raipur    Goa  10:25  14:10     1 stop via Indore
# ...       ...          ...     ...    ...    ...    ...                   ...
# 2353   IndiGo   30/10/2021  Raipur  Kochi  07:30  16:30     1 stop via Mumbai
# 2354   IndiGo   30/10/2021  Raipur  Kochi  15:05  22:10     1 stop via Mumbai
# 2355  Vistara   30/10/2021  Raipur  Kochi  08:55  18:50  1 stop via New Delhi
# 2356   IndiGo   30/10/2021  Raipur  Kochi  14:50  21:45    1 stop via Kolkata
# 2357   IndiGo   30/10/2021  Raipur  Kochi  09:00  21:45    1 stop via Kolkata
#
#          Price
# 0          NaN
# 1      ₹ 7,704
# 2      ₹ 7,704
# 3      ₹ 7,704
# 4      ₹ 8,544
# ...        ...
# 2353  ₹ 10,654
# 2354  ₹ 10,654
# 2355  ₹ 13,586
# 2356  ₹ 15,747
# 2357  ₹ 15,747
#
# [2358 rows x 8 columns]
# Lenght :  2358
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-31/10/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 19
# Time Count in Scraping  = 38
# City Count in Scraping  = 38
# spanFlightCost Count in Scraping  = 19
# pFlightStops Count in Scraping  = 19
# Transaform Function Running....
#               Airline Journey_date    From     To  Dtime  Atime  \
# 0                 NaN          NaN     NaN    NaN    NaN    NaN
# 1              IndiGo   30/10/2021  Raipur    Goa  07:30  12:40
# 2              IndiGo   30/10/2021  Raipur    Goa  08:05  14:50
# 3              IndiGo   30/10/2021  Raipur    Goa  12:10  21:20
# 4              IndiGo   30/10/2021  Raipur    Goa  10:25  14:10
# ...               ...          ...     ...    ...    ...    ...
# 2372  Vistara, IndiGo   31/10/2021  Raipur  Kochi  08:55  07:00
# 2373  Vistara, IndiGo   31/10/2021  Raipur  Kochi  08:55  07:00
# 2374        Air India   31/10/2021  Raipur  Kochi  18:50  19:15
# 2375        Air India   31/10/2021  Raipur  Kochi  18:50  19:15
# 2376        Air India   31/10/2021  Raipur  Kochi  18:00  17:20
#
#                                          Stops     Price
# 0                                          NaN       NaN
# 1                            1 stop via Mumbai   ₹ 7,704
# 2                         1 stop via New Delhi   ₹ 7,704
# 3                         1 stop via New Delhi   ₹ 7,704
# 4                            1 stop via Indore   ₹ 8,544
# ...                                        ...       ...
# 2372  3 stop via New Delhi,Hyderabad,Bengaluru  ₹ 14,691
# 2373  3 stop via New Delhi,Hyderabad,Bengaluru  ₹ 14,691
# 2374               2 stop via New Delhi,Mumbai  ₹ 16,432
# 2375               2 stop via New Delhi,Mumbai  ₹ 16,432
# 2376   3 stop via Jharsuguda,Kolkata,New Delhi  ₹ 17,556
#
# [2377 rows x 8 columns]
# Lenght :  2377
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-01/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 14
# Time Count in Scraping  = 28
# City Count in Scraping  = 28
# spanFlightCost Count in Scraping  = 14
# pFlightStops Count in Scraping  = 14
# Transaform Function Running....
#         Airline Journey_date    From     To  Dtime  Atime  \
# 0           NaN          NaN     NaN    NaN    NaN    NaN
# 1        IndiGo   30/10/2021  Raipur    Goa  07:30  12:40
# 2        IndiGo   30/10/2021  Raipur    Goa  08:05  14:50
# 3        IndiGo   30/10/2021  Raipur    Goa  12:10  21:20
# 4        IndiGo   30/10/2021  Raipur    Goa  10:25  14:10
# ...         ...          ...     ...    ...    ...    ...
# 2386  Air India   01/11/2021  Raipur  Kochi  07:45  17:20
# 2387    Vistara   01/11/2021  Raipur  Kochi  08:55  19:10
# 2388    Vistara   01/11/2021  Raipur  Kochi  20:20  09:05
# 2389  Air India   01/11/2021  Raipur  Kochi  12:30  19:15
# 2390  Air India   01/11/2021  Raipur  Kochi  18:00  17:40
#
#                                         Stops     Price
# 0                                         NaN       NaN
# 1                           1 stop via Mumbai   ₹ 7,704
# 2                        1 stop via New Delhi   ₹ 7,704
# 3                        1 stop via New Delhi   ₹ 7,704
# 4                           1 stop via Indore   ₹ 8,544
# ...                                       ...       ...
# 2386              2 stop via Nagpur,New Delhi  ₹ 11,728
# 2387                     1 stop via New Delhi  ₹ 12,291
# 2388                     1 stop via New Delhi  ₹ 12,291
# 2389          2 stop via Visakhapatnam,Mumbai  ₹ 13,111
# 2390  3 stop via Jharsuguda,Kolkata,New Delhi  ₹ 16,191
#
# [2391 rows x 8 columns]
# Lenght :  2391
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-02/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 16
# Time Count in Scraping  = 32
# City Count in Scraping  = 32
# spanFlightCost Count in Scraping  = 16
# pFlightStops Count in Scraping  = 16
# Transaform Function Running....
#               Airline Journey_date    From     To  Dtime  Atime  \
# 0                 NaN          NaN     NaN    NaN    NaN    NaN
# 1              IndiGo   30/10/2021  Raipur    Goa  07:30  12:40
# 2              IndiGo   30/10/2021  Raipur    Goa  08:05  14:50
# 3              IndiGo   30/10/2021  Raipur    Goa  12:10  21:20
# 4              IndiGo   30/10/2021  Raipur    Goa  10:25  14:10
# ...               ...          ...     ...    ...    ...    ...
# 2402  IndiGo, Vistara   02/11/2021  Raipur  Kochi  10:00  09:05
# 2403  IndiGo, Vistara   02/11/2021  Raipur  Kochi  08:40  09:05
# 2404  IndiGo, Vistara   02/11/2021  Raipur  Kochi  10:30  09:05
# 2405  IndiGo, Vistara   02/11/2021  Raipur  Kochi  09:45  09:05
# 2406  IndiGo, Vistara   02/11/2021  Raipur  Kochi  09:45  09:05
#
#                                          Stops     Price
# 0                                          NaN       NaN
# 1                            1 stop via Mumbai   ₹ 7,704
# 2                         1 stop via New Delhi   ₹ 7,704
# 3                         1 stop via New Delhi   ₹ 7,704
# 4                            1 stop via Indore   ₹ 8,544
# ...                                        ...       ...
# 2402  3 stop via Hyderabad,Bengaluru,New Delhi  ₹ 18,062
# 2403     3 stop via Mumbai,Bengaluru,New Delhi  ₹ 18,062
# 2404     3 stop via Indore,Bengaluru,New Delhi  ₹ 18,602
# 2405            2 stop via Bengaluru,New Delhi  ₹ 18,660
# 2406            2 stop via Bengaluru,New Delhi  ₹ 18,660
#
# [2407 rows x 8 columns]
# Lenght :  2407
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-03/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 13
# Time Count in Scraping  = 26
# City Count in Scraping  = 26
# spanFlightCost Count in Scraping  = 13
# pFlightStops Count in Scraping  = 13
# Transaform Function Running....
#         Airline Journey_date    From     To  Dtime  Atime  \
# 0           NaN          NaN     NaN    NaN    NaN    NaN
# 1        IndiGo   30/10/2021  Raipur    Goa  07:30  12:40
# 2        IndiGo   30/10/2021  Raipur    Goa  08:05  14:50
# 3        IndiGo   30/10/2021  Raipur    Goa  12:10  21:20
# 4        IndiGo   30/10/2021  Raipur    Goa  10:25  14:10
# ...         ...          ...     ...    ...    ...    ...
# 2415  Air India   03/11/2021  Raipur  Kochi  12:30  19:15
# 2416    Vistara   03/11/2021  Raipur  Kochi  20:20  09:05
# 2417    Vistara   03/11/2021  Raipur  Kochi  08:55  19:10
# 2418     IndiGo   03/11/2021  Raipur  Kochi  14:35  21:05
# 2419  Air India   03/11/2021  Raipur  Kochi  18:00  17:20
#
#                                         Stops     Price
# 0                                         NaN       NaN
# 1                           1 stop via Mumbai   ₹ 7,704
# 2                        1 stop via New Delhi   ₹ 7,704
# 3                        1 stop via New Delhi   ₹ 7,704
# 4                           1 stop via Indore   ₹ 8,544
# ...                                       ...       ...
# 2415          2 stop via Visakhapatnam,Mumbai  ₹ 11,431
# 2416                     1 stop via New Delhi  ₹ 12,291
# 2417                     1 stop via New Delhi  ₹ 12,469
# 2418                        1 stop via Mumbai  ₹ 14,739
# 2419  3 stop via Jharsuguda,Kolkata,New Delhi  ₹ 17,031
#
# [2420 rows x 8 columns]
# Lenght :  2420
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-04/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 17
# Time Count in Scraping  = 34
# City Count in Scraping  = 34
# spanFlightCost Count in Scraping  = 17
# pFlightStops Count in Scraping  = 17
# Transaform Function Running....
#         Airline Journey_date    From     To  Dtime  Atime  \
# 0           NaN          NaN     NaN    NaN    NaN    NaN
# 1        IndiGo   30/10/2021  Raipur    Goa  07:30  12:40
# 2        IndiGo   30/10/2021  Raipur    Goa  08:05  14:50
# 3        IndiGo   30/10/2021  Raipur    Goa  12:10  21:20
# 4        IndiGo   30/10/2021  Raipur    Goa  10:25  14:10
# ...         ...          ...     ...    ...    ...    ...
# 2432  Air India   04/11/2021  Raipur  Kochi  07:45  11:25
# 2433  Air India   04/11/2021  Raipur  Kochi  12:30  19:15
# 2434  Air India   04/11/2021  Raipur  Kochi  18:50  19:15
# 2435  Air India   04/11/2021  Raipur  Kochi  18:50  19:15
# 2436  Air India   04/11/2021  Raipur  Kochi  18:00  17:20
#
#                                              Stops     Price
# 0                                              NaN       NaN
# 1                                1 stop via Mumbai   ₹ 7,704
# 2                             1 stop via New Delhi   ₹ 7,704
# 3                             1 stop via New Delhi   ₹ 7,704
# 4                                1 stop via Indore   ₹ 8,544
# ...                                            ...       ...
# 2432  4 stop via Nagpur,New Delhi,Bengaluru,Mysore  ₹ 12,327
# 2433               2 stop via Visakhapatnam,Mumbai  ₹ 13,111
# 2434                   2 stop via New Delhi,Mumbai  ₹ 15,697
# 2435                   2 stop via New Delhi,Mumbai  ₹ 15,697
# 2436       3 stop via Jharsuguda,Kolkata,New Delhi  ₹ 17,556
#
# [2437 rows x 8 columns]
# Lenght :  2437
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-05/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
# Webpage found ...
# Scrolling document upto bottom ...
# Closing Chrome ...
# Getting data from DOM ...
# spanFlightName  = 14
# Time Count in Scraping  = 28
# City Count in Scraping  = 28
# spanFlightCost Count in Scraping  = 14
# pFlightStops Count in Scraping  = 14
# Transaform Function Running....
#         Airline Journey_date    From     To  Dtime  Atime  \
# 0           NaN          NaN     NaN    NaN    NaN    NaN
# 1        IndiGo   30/10/2021  Raipur    Goa  07:30  12:40
# 2        IndiGo   30/10/2021  Raipur    Goa  08:05  14:50
# 3        IndiGo   30/10/2021  Raipur    Goa  12:10  21:20
# 4        IndiGo   30/10/2021  Raipur    Goa  10:25  14:10
# ...         ...          ...     ...    ...    ...    ...
# 2446    Vistara   05/11/2021  Raipur  Kochi  20:20  09:05
# 2447     IndiGo   05/11/2021  Raipur  Kochi  11:30  22:45
# 2448  Air India   05/11/2021  Raipur  Kochi  18:50  19:15
# 2449  Air India   05/11/2021  Raipur  Kochi  18:50  19:15
# 2450    Vistara   05/11/2021  Raipur  Kochi  08:55  19:10
#
#                             Stops     Price
# 0                             NaN       NaN
# 1               1 stop via Mumbai   ₹ 7,704
# 2            1 stop via New Delhi   ₹ 7,704
# 3            1 stop via New Delhi   ₹ 7,704
# 4               1 stop via Indore   ₹ 8,544
# ...                           ...       ...
# 2446         1 stop via New Delhi  ₹ 13,586
# 2447         1 stop via New Delhi  ₹ 17,243
# 2448  2 stop via New Delhi,Mumbai  ₹ 17,356
# 2449  2 stop via New Delhi,Mumbai  ₹ 17,356
# 2450         1 stop via New Delhi  ₹ 18,414
#
# [2451 rows x 8 columns]
# Lenght :  2451
#
# Requesting URL: https://www.makemytrip.com/flight/search?itinerary=RPR-COK-06/11/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&=&cabinClass=E
