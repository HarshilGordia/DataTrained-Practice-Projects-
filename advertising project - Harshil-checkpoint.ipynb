# %%
import pandas as pd

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('advertising.csv')

# %%
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   radio       200 non-null    float64
#  3   newspaper   200 non-null    float64
#  4   sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# TV            float64
# radio         float64
# newspaper     float64
# sales         float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'TV', 'radio', 'newspaper', 'sales'], dtype='object')

# %%
df.values
# Out:
# array([[  1. , 230.1,  37.8,  69.2,  22.1],
#        [  2. ,  44.5,  39.3,  45.1,  10.4],
#        [  3. ,  17.2,  45.9,  69.3,   9.3],
#        [  4. , 151.5,  41.3,  58.5,  18.5],
#        [  5. , 180.8,  10.8,  58.4,  12.9],
#        [  6. ,   8.7,  48.9,  75. ,   7.2],
#        [  7. ,  57.5,  32.8,  23.5,  11.8],
#        [  8. , 120.2,  19.6,  11.6,  13.2],
#        [  9. ,   8.6,   2.1,   1. ,   4.8],
#        [ 10. , 199.8,   2.6,  21.2,  10.6],
#        [ 11. ,  66.1,   5.8,  24.2,   8.6],
#        [ 12. , 214.7,  24. ,   4. ,  17.4],
#        [ 13. ,  23.8,  35.1,  65.9,   9.2],
#        [ 14. ,  97.5,   7.6,   7.2,   9.7],
#        [ 15. , 204.1,  32.9,  46. ,  19. ],
#        [ 16. , 195.4,  47.7,  52.9,  22.4],
#        [ 17. ,  67.8,  36.6, 114. ,  12.5],
#        [ 18. , 281.4,  39.6,  55.8,  24.4],
#        [ 19. ,  69.2,  20.5,  18.3,  11.3],
#        [ 20. , 147.3,  23.9,  19.1,  14.6],
#        [ 21. , 218.4,  27.7,  53.4,  18. ],
# ...

# %%
df.shape
# Out:
# (200, 5)

# %%
df.isnull()
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0         False  False  False      False  False
# 1         False  False  False      False  False
# 2         False  False  False      False  False
# 3         False  False  False      False  False
# 4         False  False  False      False  False
# ..          ...    ...    ...        ...    ...
# 195       False  False  False      False  False
# 196       False  False  False      False  False
# 197       False  False  False      False  False
# 198       False  False  False      False  False
# 199       False  False  False      False  False
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       radio   newspaper       sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.value_counts()
# Out:
# Unnamed: 0  TV     radio  newspaper  sales
# 1           230.1  37.8   69.2       22.1     1
# 138         273.7  28.9   59.7       20.8     1
# 128         80.2   0.0    9.2        8.8      1
# 129         220.3  49.0   3.2        24.7     1
# 130         59.6   12.0   43.1       9.7      1
#                                              ..
# 70          216.8  43.9   27.2       22.3     1
# 71          199.1  30.6   38.7       18.3     1
# 72          109.8  14.3   31.7       12.4     1
# 73          26.8   33.0   19.3       8.8      1
# 200         232.1  8.6    8.7        13.4     1
# Length: 200, dtype: int64

# %%
df.sales.value_counts()
# Out:
# 9.7     5
# 15.9    4
# 11.7    4
# 12.9    4
# 20.7    3
#        ..
# 25.5    1
# 15.6    1
# 17.6    1
# 3.2     1
# 20.8    1
# Name: sales, Length: 121, dtype: int64

# %%
dfcor=df.corr()
dfcor
# Out:
#             Unnamed: 0        TV     radio  newspaper     sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
sns.heatmap(dfcor,cmap='Blues',annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.scatter(df['TV'],df['sales'])

# %% [markdown]
# This scatter plot shows as the advertises on TV increse sales also increase

# %%
plt.scatter(df['radio'],df['sales'])

# %% [markdown]
# Here we can observe that as advertises on radio increases sales also increases but not as much as compared to TV

# %%
plt.scatter(df['newspaper'],df['sales'])

# %% [markdown]
# Increase in newpaper ads, sales does not increase that much

# %%
sns.pairplot(df,x_vars=['TV','radio','newspaper'],y_vars=['sales'],kind='scatter')

# %% [markdown]
# By looking at this we can compare effects of ads on TV, radio and newspaper to sales.

# %%
sns.histplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Count'>

# %% [markdown]
# Here we can observe that 200-225 ads on TV gives the highest sales.

# %%
sns.histplot(df['radio'])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Count'>

# %%
sns.histplot(df['newspaper'])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Count'>

# %% [markdown]
# We can observe that increas in ads on newspaper does not icrease sales

# %%
cols_sns = ['TV','radio','newspaper','sales']
sns.set(style="ticks")
sns.pairplot(df[cols_sns],hue="sales")

# %%
fig, axs= plt.subplots(3, figsize=(8,8))
plt1 = sns.boxplot(df['TV'],ax=axs[0])
plt2 = sns.boxplot(df['radio'],ax=axs[1])
plt3 = sns.boxplot(df['newspaper'],ax=axs[2])

# %% [markdown]
# Here we can observe that TV has the highest sales and higest mean compared to radio and newspaper. Newspaper has very less outliers present.

# %%
sns.boxplot(df['sales'])
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# Sales has the mean of nearly 12.

# %%
df.skew()
# Out:
# Unnamed: 0    0.000000
# TV           -0.069853
# radio         0.094175
# newspaper     0.894720
# sales         0.407571
# dtype: float64

# %%
sns.distplot(df['TV'])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Density'>

# %% [markdown]
# WE can observe normal distribution

# %%
sns.distplot(df['radio'])
# Out:
# <AxesSubplot:xlabel='radio', ylabel='Density'>

# %% [markdown]
# This graph is normally distributed

# %%
sns.distplot(df['newspaper'])
# Out:
# <AxesSubplot:xlabel='newspaper', ylabel='Density'>

# %% [markdown]
# This graph is slightly positively distributed

# %%
sns.distplot(df['sales'])
# Out:
# <AxesSubplot:xlabel='sales', ylabel='Density'>

# %% [markdown]
# This is normally distributed

# %%
x=df.drop(columns='sales')
y=df['sales']

# %%
print(x)
print(x.shape)
# Out:
#      Unnamed: 0     TV  radio  newspaper
# 0             1  230.1   37.8       69.2
# 1             2   44.5   39.3       45.1
# 2             3   17.2   45.9       69.3
# 3             4  151.5   41.3       58.5
# 4             5  180.8   10.8       58.4
# ..          ...    ...    ...        ...
# 195         196   38.2    3.7       13.8
# 196         197   94.2    4.9        8.1
# 197         198  177.0    9.3        6.4
# 198         199  283.6   42.0       66.2
# 199         200  232.1    8.6        8.7
#
# [200 rows x 4 columns]
# (200, 4)

# %%
print(y)
print(y.shape)
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64
# (200,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.3,random_state=100)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (140, 4)
# (60, 4)
# (140,)
# (60,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# 2.7265189671982917

# %%
lr.coef_
# Out:
# array([-0.00072061,  0.04545001,  0.18977137,  0.00432698])

# %%
predlr=lr.predict(x_test)

# %%
print(np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# 1.3619355668849231

# %%
lr.score(x_train,y_train)
# Out:
# 0.8928613136889041

# %%
print('predicted',predlr)
print('\n')
print('actual \n',y_test)
# Out:
# predicted [10.59056288 20.00913801 16.91137367 19.16660194 20.9427758  13.07527261
#  11.79334998 12.32727044 20.60852325 20.9782953  10.7473639  19.51789691
#   6.35914557 15.19561811  8.95033363  7.83087748 16.17168871 11.966368
#  17.05502125 11.30380879 17.04780954  9.7715562  20.8769128  17.24672294
#  15.13999812 21.95884066 19.17235681 10.08207959 19.36765911 14.85180325
#  14.37363477  7.58377725  9.92124052 14.71747349  7.15675908 13.61696459
#   7.53494617 11.65767611 13.41040002 15.22156404 17.12250601 13.56352033
#  14.25042077 13.66951927 11.9535571   8.80272584 12.11969865 19.25547564
#   9.12655405  5.0833357  16.269235   18.09818195 12.92625357 16.8854399
#  17.89809565 12.40076495  4.28397614 11.23263976 16.08030326 13.51198086]
#
#
# actual
#  126     6.6
# 104    20.7
# 99     17.2
# 92     19.4
# 111    21.8
# 167    12.2
# 116    12.2
# 96     11.7
# 52     22.6
# 69     22.3
# 164    11.9
# 124    19.7
# 182     8.7
# 154    15.6
# 125    10.6
# 196     9.7
# ...

# %%
print('error')

print('Mean absolute error:', mean_absolute_error(y_test,predlr))
print('Mean squared error:', mean_squared_error(y_test,predlr))

print('Root Mean Squared Error:', np.sqrt(mean_squared_error(y_test,predlr)))
# Out:
# error
# Mean absolute error: 1.0659270518465658
# Mean squared error: 1.8548684883461568
# Root Mean Squared Error: 1.3619355668849231

# %%
from sklearn.metrics import r2_score
print(r2_score(y_test,predlr))
# Out:
# 0.9056492582804204

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lr,x,y,cv=3)
print(score)
print(score.mean())
# Out:
# [0.90345241 0.8652026  0.90540693]
# 0.8913539823868293

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVC
svc=SVC(probability=True,kernel='linear')

#create adaboostclassifier object
ad=AdaBoostRegressor()
ad.fit(x_train,y_train)

ad_pred=ad.predict(x_test)
print(mean_squared_error(y_test,ad_pred))
print('Mean absolute error:', mean_absolute_error(y_test,ad_pred))
print(r2_score(y_test,ad_pred))
# Out:
# 0.735536519413979
# Mean absolute error: 0.7317979942324938
# 0.9625858023873034

# %%
adscores=cross_val_score(ad,x,y,cv=5)
print(adscores)
print(adscores.mean(),adscores.std())
# Out:
# [0.95585303 0.97047919 0.9458556  0.9363755  0.95427204]
# 0.9525670730909896 0.011329247391945975

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
print(mean_squared_error(y_test,predrf))
print('Mean absolute error:', mean_absolute_error(y_test,predrf))
print(r2_score(y_test,predrf))
# Out:
# 0.5141215000000001
# Mean absolute error: 0.5650999999999992
# 0.9738484182766869

# %%
rfscores=cross_val_score(rf,x,y,cv=5)
print(rfscores)
print(rfscores.mean(),rfscores.std())
# Out:
# [0.97692329 0.98254963 0.96218086 0.95918079 0.97779713]
# 0.9717263407339122 0.009268368558777128

# %%
sns.regplot(y_test,ad_pred)
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# This is regression plot for AdaBoostRegressor model

# %%
sns.regplot(y_test,predlr)
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# This is regression plot for LinearRegression model

# %%
sns.regplot(y_test,predrf)
# Out:
# <AxesSubplot:xlabel='sales'>

# %% [markdown]
# This is regression plot for RandomForesRegressor model

# %%
sns.distplot(ad_pred,bins=10)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Checking the distribution of predicted AdaBoostRegressor model

# %%
sns.distplot(predlr,bins=10)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Checking the distribution of predicted LinearRegression model

# %%
sns.distplot(predrf,bins=10)
# Out:
# <AxesSubplot:ylabel='Density'>

# %% [markdown]
# Checking the distribution of predicted RandomForestRegressor model

# %% [markdown]
# # Saving the model

# %%
import joblib
#from sklearn.externals import jobib

#save the model as a object file
joblib.dump(rf,'rffile.obj')
#load the model from the file

rf_from_joblib= joblib.load('rffile.obj')

#use the loaded model to make predictions

rf_from_joblib.predict(x_test)
# Out:
# array([ 5.971, 19.895, 16.927, 19.43 , 22.088, 12.124, 13.07 , 11.792,
#        21.836, 22.394, 12.484, 19.823,  8.921, 15.439,  9.854,  9.627,
#        15.707, 12.618, 17.519, 12.709, 16.519, 11.182, 22.344, 17.669,
#        15.33 , 23.438, 19.678, 11.397, 20.925, 14.579, 13.282,  9.893,
#        11.776, 14.739,  9.549, 14.034,  9.296, 12.549, 11.949, 14.675,
#        16.282, 14.655, 14.84 , 12.269, 12.93 ,  9.937,  8.014, 19.575,
#        11.16 ,  8.968, 16.034, 18.746, 13.449, 16.138, 18.575, 11.615,
#         7.047,  7.655, 15.846, 13.974])

# %% [markdown]
# # Hyperparmeter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'max_features': ['auto', 'log2']}
rf = RandomForestRegressor()
gr_search = GridSearchCV(estimator =rf,param_grid = param_grid,cv=5)
gr_search.fit(x_train, y_train)


print(gr_search.best_params_)
print(gr_search.best_score_)
# Out:
# {'max_features': 'auto'}
# 0.96797031742634

# %%
param_grid = {'n_estimators': [50, 100], 
                   'learning_rate': [0.01, 0.05, 0.1, 0.5], 
                   'loss': ['linear', 'square', 'exponential']},
ad= AdaBoostRegressor()
ad_gr_search = GridSearchCV(estimator =ad,param_grid = param_grid,cv=5)
ad_gr_search.fit(x_train, y_train)


print(ad_gr_search.best_params_)
print(ad_gr_search.best_score_)
# Out:
# {'learning_rate': 0.5, 'loss': 'linear', 'n_estimators': 100}
# 0.9454009888943148

# %% [markdown]
# # Training the model with best extracted parameter

# %%
rf = RandomForestRegressor(max_features = 'auto')
rf.fit(x,y)
rf.score(x,y)
# Out:
# 0.9971695054524763
